# %%
import os 
import gzip 
import glob 
import xmltodict 
import polars as pl 
import pandas as pd 
import pyarrow as pa 

pd.set_option('display.max_columns',100)

colonnes_pd_budget = ['Id_Fichier',
    'Nomenclature',
    'Exer' ,
    'TypOpBudg' , #des 2 et des 1
    'Operation',
    'Nature',
    'ContNat',
    'LibCpte',
    'Fonction',
    'ContFon',
    'ArtSpe', 
    'CodRD', 
    'MtBudgPrec', 
    'MtRARPrec', 
    'MtPropNouv', 
    'MtPrev', 
    'OpBudg',
    'CredOuv', 
    'MtReal', 
    'MtRAR3112', 
    'ContOp',
    'OpeCpteTiers',
    'MtSup',
    'APVote',
    'Brut',
    'BudgetHorsRAR',
    'Comp',
    'ICNE',
    'ICNEPrec',
    'MtOpeCumul',
    'MtOpeInfo',
    'Net',
    'ProdChaRat',
    'RARPrec',
    'CaracSup',
    'TypOpe',
    'Section',
    'ChapSpe',
    'ProgAutoLib',
    'ProgAutoNum',
    'VirCredNum',
    'CodeRegion']

colonnes_doc_budgetaire = [
 'Id_Fichier',
 'Nomenclature',
 'Exer',
 'IdColl',
 'Siren',
 'CodColl',
 'LibelleColl',
 'DteStr',
 '@date',
 'DteDec',
 'DteDecEx',
 'NumDec',
 'IdPost',
 'LibellePoste',
 'LibelleEtabPal',
 'IdEtabPal',
 'LibelleEtab',
 'IdEtab',
 'NatDec',
 'NatVote', 	
 'OpeEquip', 
 'CodInseeColl',	
 'VoteFormelChap', 	
 'TypProv', 	
 'BudgPrec',
 'RefProv',	
 'ReprRes', 	
 'NatFonc', 	
 'PresentationSimplifiee', 	
 'DepFoncN2',	
 'RecFoncN2' ,	
 'DepInvN2' ,	
 'RecInvN2' ,	
 'CodTypBud',
 'CodBud',
 'ProjetBudget',  	
 'Affect',
 'SpecifBudget',
 'FinJur',	 	
 '@md5',	
 '@sha1']

# %%
def _isolement_id(fichier) : 
 '''Extrait l'id du nom du fichier pour la liste comprehension de securité

 ATTENTION, le premier split / va changer si on l'applique sur du minio '''
 val_id_fichier_source = fichier.split("/")[-1].split('.')[0]
 if '-' in val_id_fichier_source : 
  val_id_fichier = val_id_fichier_source.split('-')[1]
 else : 
  val_id_fichier= val_id_fichier_source
 return val_id_fichier

def parse_fichier(chemin) : 
 '''Ouvre et parse le fichier gzip'''
 with gzip.open(chemin, 'rb') as fichier_ouvert : 
  fichier_xml_gzip = fichier_ouvert.read()
  fichier_xml = fichier_xml_gzip.decode('latin-1')
  fichier_dict = xmltodict.parse(fichier_xml)
 return fichier_dict

def extraction_annexe(chemin_annexe, dict_metadonnees) : 
 liste_annexe = []
 for row in chemin_annexe : 
  liste_par_ligne = {}
  for a, b in row.items() : 
   liste_par_ligne.update({a : b.get('@V')})
   liste_par_ligne.update(dict_metadonnees)
  liste_annexe.append(liste_par_ligne)
 return liste_annexe 

def extraction_donnees(chemin) : 
 dict_annexe = {}
 for a, b in chemin.items() : 
   dict_annexe.update({a : b.get('@V')})
 return dict_annexe 

def extraction_lignes_budget_liste(chemin, dict_id) :
 liste_budget = []
 for lignes in chemin : 
  dict_ligne = {}
  dict_ligne.update(dict_id)
  for a, b in lignes.items() :
     if a not in ['MtSup', 'CaracSup'] : 
       dict_ligne.update({a : b.get('@V')}) 
 
     elif a == 'MtSup' : 
       dict_ligne.update({a : b})
       type_m = lignes.get('MtSup')
 
       if isinstance(type_m, dict) : 
        dict_ligne.update({type_m.get('@Code') : type_m.get('@V')})
 
       elif isinstance(type_m, list) : 
          for j in b : 
           dict_ligne.update({j.get('@Code') : j.get('@V')})
 
     elif a == 'CaracSup' :   
       dict_ligne.update({a : b})
       type_c = lignes.get('CaracSup')
 
       if isinstance(type_c, dict) :
        dict_ligne.update({type_c.get('@Code') : type_c.get('@V')})
 
       elif isinstance(type_c, list) : 
          for j in b : 
           dict_ligne.update({j.get('@Code') : j.get('@V')})

  liste_budget.append(dict_ligne)
 return liste_budget

def extraction_budget(fichier_parse, dict_id) : 
 ''' Extrait toutes les données budgetaires, y compris carac et mtsup '''
 lignes_budget = fichier_parse['DocumentBudgetaire']['Budget']['LigneBudget'] 

 if isinstance(lignes_budget, dict) : 
  donnees_budget_prep = extraction_donnees(lignes_budget)
  donnees_budget_prep.update(dict_id)
  donnees_budget = [donnees_budget_prep]

 elif isinstance(lignes_budget, list) : 
  donnees_budget = extraction_lignes_budget_liste(lignes_budget, dict_id)

 df_budget = pd.DataFrame(donnees_budget)
 df_colonnes = pd.DataFrame(columns=colonnes_pd_budget)
 df_budget_sans_schema = pd.concat([df_colonnes, df_budget])
 df_budget_propre = nettoyage_budget(df_budget_sans_schema)
 return df_budget_propre

# %%
def extraction_document_budgetaire(fichier_parse, dictionnaire_id) : 
  ''' Extrait les métadonnées du fichier pour la table document_budgetaire '''
  blocbudget = extraction_donnees(fichier_parse['DocumentBudgetaire']['Budget']['BlocBudget'])
  entetedocbudg = extraction_donnees(fichier_parse['DocumentBudgetaire']['EnTeteDocBudgetaire'])
  entetebudget = extraction_donnees(fichier_parse['DocumentBudgetaire']['Budget']['EnTeteBudget'])
  scellement = fichier_parse['DocumentBudgetaire']['Scellement']

  liste_fichier = [{**blocbudget, **entetedocbudg, **entetebudget, **scellement, **dictionnaire_id}]
  df_doc_budgetaire_prep_1 = pd.DataFrame(liste_fichier)
  df_colonnes_budg = pd.DataFrame(columns= colonnes_doc_budgetaire)
  df_doc_budgetaire_prep_2 = pd.concat([df_colonnes_budg, df_doc_budgetaire_prep_1])
  df_doc_budgetaire = nettoyage_doc_budg(df_doc_budgetaire_prep_2)
  return df_doc_budgetaire

# %%
def extraction_annexe_concours(fichier_parse, dictionnaire_id) : 
 ''' Extrait les données de l'annexe concours pour la table correspondante 
 # !! Necessite un try si Data_concours n'est pas dans le fichier '''
 concours = fichier_parse['DocumentBudgetaire']['Budget']['Annexes']['DATA_CONCOURS']['CONCOURS']
 liste_donnees_concours = extraction_annexe(concours, dictionnaire_id)
 df_concours = pd.DataFrame(liste_donnees_concours)
 return df_concours

# %%
def nettoyage_budget(df) : 
 df['Id_Fichier'] = df['Id_Fichier'].astype('Int32')
 df['Nomenclature'] = df['Nomenclature'].astype(str)
 df['Exer'] = df['Exer'].astype('Int16')
 df['TypOpBudg'] = df['TypOpBudg'].astype('Int32')
 #df['Operation'] = df['Operation'].astype('Int16') #12VEM488 , aire de jeux etc
 df['ArtSpe'] = df['ArtSpe'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['MtBudgPrec'] = df['MtBudgPrec'].astype(float)
 df['MtRARPrec'] = df['MtRARPrec'].astype(float)
 df['MtPropNouv'] = df['MtPropNouv'].astype(float)
 df['MtPrev'] = df['MtPrev'].astype(float)
 df['OpBudg'] = df['OpBudg'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['CredOuv'] = df['CredOuv'].astype(float)
 df['MtReal'] = df['MtReal'].astype(float)
 df['MtRAR3112'] = df['MtRAR3112'].astype(float)
 #df['ContOp'] = df['ContOp'].replace('', None).astype('Int16') #contient des '16 01'
 df['APVote'] = df['APVote'].astype(float)
 df['Brut'] = df['Brut'].astype(float)
 df['BudgetHorsRAR'] = df['BudgetHorsRAR'].astype(float)
 df['ICNE'] = df['ICNE'].astype(float)
 df['ICNEPrec'] = df['ICNEPrec'].astype(float)
 df['MtOpeCumul'] = df['MtOpeCumul'].astype(float)
 df['MtOpeInfo'] = df['MtOpeInfo'].astype(float)
 df['Net'] = df['Net'].astype(float)
 df['ProdChaRat'] = df['ProdChaRat'].astype(float)
 df['TypOpe'] = df['TypOpe'].astype('Int32')
 df['CodeRegion'] = df['CodeRegion'].astype('Int16')
 return df 

def nettoyage_doc_budg(df) : 
 df = df.drop(columns=['NatCEPL', 'Departement'])
 df = df.rename(columns={'IdColl' : 'Siret', '@date' : 'date_precise',
                    '@md5' : 'md5', '@sha1' : 'sha1'}) 
 
 df['Id_Fichier'] = df['Id_Fichier'].astype('Int32')
 df['Exer'] = df['Exer'].astype('Int16')
 df['Siren'] = df['Siret'].str.slice(0,9)
 df['Siret'] = df['Siret'].astype('Int64')
 df['Siren'] = df['Siren'].astype('Int64')
 df['DteStr'] = pd.to_datetime(df['DteStr'])
 df['DteDec'] = pd.to_datetime(df['DteDec'], errors= 'coerce')
 df['date_precise'] = pd.to_datetime(df['date_precise'], format='ISO8601', utc= True)
 df['DteDecEx'] = pd.to_datetime(df['DteDecEx'])
 df['IdEtabPal'] = df['IdEtabPal'].astype('Int64')
 df['IdEtab'] = df['IdEtab'].astype('Int64')
 df['OpeEquip'] = df['OpeEquip'].replace(
     {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['VoteFormelChap'] = df['VoteFormelChap'].replace(
     {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['TypProv'] = df['TypProv'].astype('Int16')
 df['BudgPrec'] = df['BudgPrec'].astype('Int16')
 df['ReprRes'] = df['ReprRes'].astype('Int16')
 df['NatFonc'] = df['NatFonc'].astype('Int16')
 df['PresentationSimplifiee'] = df['PresentationSimplifiee'].replace(
     {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['DepFoncN2'] = df['DepFoncN2'].astype(float)
 df['RecFoncN2'] = df['RecFoncN2'].astype(float)
 df['DepInvN2'] = df['DepInvN2'].astype(float)
 df['RecInvN2'] = df['RecInvN2'].astype(float)
 df['ProjetBudget'] = df['ProjetBudget'].replace(
     {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
 df['SpecifBudget'] = df['SpecifBudget'].astype('Int64')
 df['FinJur'] = df['FinJur'].astype('Int64')
 return df

# %% [markdown]
# --------------------------------------------------------------
#
# Optionnel, explo :

# %%
def multi_document(chemin_des_xml) :
 ''' Changement à faire : 
 Faire extraire l'Id_Fichier'''
 chemin_xml_entree_glob = glob.glob(os.path.join(chemin_des_xml, "*.gz"))
 #connection à la table
 liste_df = []

 for fichier in chemin_xml_entree_glob : 
  id_fichier = _isolement_id(fichier)
  #print(id_fichier)
  #Necessite verif dans tables
  if id_fichier is None : 
   print('vide')
   pass 
  else : 
   try : 
    #print('etape 2')
    fichier_parse = parse_fichier(fichier)
    dict_metadonnees = {'Id_Fichier' : id_fichier}
    #print(dict_metadonnees)
    df_doc = extraction_document_budgetaire(fichier_parse, dict_metadonnees)
    liste_df.append(df_doc)
    #insertion dans table
   except Exception as e : 
     print(id_fichier, 'erreur')
     print(e)
 
 df_mega = pd.concat(liste_df)
 return df_mega

# %%
df_doc1 = multi_document(chemin_20)
# Out:
# 775775 erreur
# no element found: line 1, column 0

# %%
df_doc1['FinJur'].value_counts()
# Out:
# FinJur
# 910811363         2
# 9308127722        1
# 05                1
# 21590017600011    1
# 380790386         1
# Name: count, dtype: int64

# %%
#df_doc1 = df_doc1.drop(columns=['NatCEPL', 'Departement'])
df_doc1 = df_doc1.rename(columns={'IdColl' : 'Siret'})

# %%
df_doc1['Id_Fichier'] = df_doc1['Id_Fichier'].astype('Int32')
df_doc1['Exer'] = df_doc1['Exer'].astype('Int16')
#df_doc1['Siren'] = df_doc1['Siret'].str.slice(0,9)
#df_doc1['Siret'] = df_doc1['Siret'].astype('Int64')
#df_doc1['Siren'] = df_doc1['Siren'].astype('Int64')
df_doc1['DteStr'] = pd.to_datetime(df_doc1['DteStr'])
df_doc1['DteDec'] = pd.to_datetime(df_doc1['DteDec'], errors= 'coerce')
df_doc1['@date'] = pd.to_datetime(df_doc1['@date'], format='ISO8601', utc= True)
df_doc1['DteDecEx'] = pd.to_datetime(df_doc1['DteDecEx'])
df_doc1['IdEtabPal'] = df_doc1['IdEtabPal'].astype('Int64')
df_doc1['IdEtab'] = df_doc1['IdEtab'].astype('Int64')
df_doc1['OpeEquip'] = df_doc1['OpeEquip'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
df_doc1['VoteFormelChap'] = df_doc1['VoteFormelChap'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
df_doc1['TypProv'] = df_doc1['TypProv'].astype('Int16')
df_doc1['BudgPrec'] = df_doc1['BudgPrec'].astype('Int16')
df_doc1['ReprRes'] = df_doc1['ReprRes'].astype('Int16')
df_doc1['NatFonc'] = df_doc1['NatFonc'].astype('Int16')
df_doc1['PresentationSimplifiee'] = df_doc1['PresentationSimplifiee'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
df_doc1['DepFoncN2'] = df_doc1['DepFoncN2'].astype(float)
df_doc1['RecFoncN2'] = df_doc1['RecFoncN2'].astype(float)
df_doc1['DepInvN2'] = df_doc1['DepInvN2'].astype(float)
df_doc1['RecInvN2'] = df_doc1['RecInvN2'].astype(float)
df_doc1['ProjetBudget'] = df_doc1['ProjetBudget'].replace(
    {'0' : False, '1' : True, 'false' : False, "true" : True}).astype(bool)
df_doc1['SpecifBudget'] = df_doc1['SpecifBudget'].astype('Int64')
df_doc1['FinJur'] = df_doc1['FinJur'].astype('Int64')


df_doc1.head()
# Out:
#    Id_Fichier          Nomenclature  Exer           Siret      Siren CodColl  \
# 0      671182              M4-M49_D  2020  25540368500027  255403685     434
# 0      815288   M14-M14_COM_SUP3500  2021  20007067000191  200070670     050
# 0      618507              M4-M49_D  2019  21350002800096  213500028     413
# 0      653656  M14-M14_COM_500_3500  2020  21560146900095  215601469     301
# 0      687838  M14-M14_COM_500_3500  2020  21430062600014  214300626     206
#
#                  LibelleColl     DteStr                            @date  \
# 0                 SDAA54 M49 2021-03-25 2021-03-25 10:17:22.986000+00:00
# 0   ZA BUDAN PLEINE-FOUGERES 2021-01-01 2022-01-31 09:57:22.066000+00:00
# 0     ASSAINISSEMENT AMANLIS 2019-01-01        2020-08-13 15:35:46+00:00
# 0  LOTISSEMENT ESPACE AMEDEE 2020-01-01        2021-02-22 16:15:27+00:00
# 0                  CHASPUZAC 2021-03-23 2021-03-25 12:42:20.421000+00:00
#
#       DteDec   DteDecEx NumDec  IdPost  \
# 0 2021-03-23 2021-03-25    NaN  054011
# 0 2021-01-01 2021-01-01    NaN  035045
# 0 2019-01-01 2019-01-01    NaN  035034
# 0 2020-01-01 2020-01-01    NaN  056038
# 0        NaT        NaT    NaN  043030
#
#                                LibellePoste  \
# 0                   Trésorerie de Maxéville
# 0             CENTRE DES FINANCES PUBLIQUES
# 0  CENTRE DES FINANCES PUBLIQUES DE RETIERS
# 0              CENTRE DES FINANCES PUBLIQUE
# 0                 TRESORERIE LE PUY-ST-JEAN
#
#                                       LibelleEtabPal       IdEtabPal  \
# 0  syndicat départemental d'assaissinissement aut...  25540368500019
# 0                 CC PAYS DOL BAIE MONT SAINT-MICHEL  20007067000019
# 0                                  COMMUNE D AMANLIS  21350002800013
# 0                                                NaN            <NA>
# 0                                                NaN            <NA>
#
#                  LibelleEtab          IdEtab NatDec NatVote  OpeEquip  \
# 0                 SDAA54 M49  25540368500027     09    FcIc     False
# 0   ZA BUDAN PLEINE-FOUGERES  20007067000191     09    FcIc      True
# 0     ASSAINISSEMENT AMANLIS  21350002800096     09    FcIc     False
# 0  LOTISSEMENT ESPACE AMEDEE  21560146900095     09    FcIc     False
# 0       COMMUNE DE CHASPUZAC  21430062600014     09    FcIc      True
#
#   CodInseeColl  VoteFormelChap  TypProv  BudgPrec RefProv  ReprRes  NatFonc  \
# 0                        False        1         2     NaN        3        1
# 0          NaN           False        1         1     NaN        3        1
# 0                        False        1         2                3        1
# 0                        False        1         2                3        1
# 0        43062           False        1         2     NaN        3        1
#
#    PresentationSimplifiee  DepFoncN2  RecFoncN2  DepInvN2  RecInvN2 CodTypBud  \
# 0                   False        0.0        0.0       0.0       0.0         A
# 0                    True        0.0        0.0       0.0       0.0         A
# 0                   False        0.0        0.0       0.0       0.0         A
# 0                   False        0.0        0.0       0.0       0.0         P
# 0                    True        NaN        NaN       NaN       NaN         P
#
#   CodBud  ProjetBudget Affect  SpecifBudget  FinJur  \
# 0     00          True    NaN          <NA>    <NA>
# 0     16         False    NaN          <NA>    <NA>
# 0     00         False                 <NA>    <NA>
# 0     00         False                 <NA>    <NA>
# 0     00         False    NaN          <NA>    <NA>
#
#                                @md5                                     @sha1
# 0  B7DFD2AD2AF730F68F6E7D65E6C77AB4  86DE552F22F3445EB85F0445A42E312B8D65F8B2
# 0  B0C9D982A0A2D619AB6131C0719D3FC9  7E2C610430F21DEF6C2DE0DFA5DFC3D3F4E84A6B
# 0  4203FB8AC4864957537E079846456939  22ABF0D1B2B3981AF017D1DD53A231E304EAC8F3
# 0  8DA2060B9C49D192BF1C95C85FFBA0C8  11BD944F301E635062355A5E88CE094505D73566
# 0  65A88195E80AB330DBC2BCA5C2932E9E  8B05CDA876A142A4264551467AA121892C254B4F

# %%
df_doc1.dtypes
# Out:
# Id_Fichier                              Int32
# Nomenclature                           object
# Exer                                    Int16
# Siret                                   Int64
# Siren                                   Int64
# CodColl                                object
# LibelleColl                            object
# DteStr                         datetime64[ns]
# @date                     datetime64[ns, UTC]
# DteDec                         datetime64[ns]
# DteDecEx                       datetime64[ns]
# NumDec                                 object
# IdPost                                 object
# LibellePoste                           object
# LibelleEtabPal                         object
# IdEtabPal                               Int64
# LibelleEtab                            object
# IdEtab                                  Int64
# NatDec                                 object
# NatVote                                object
# OpeEquip                                 bool
# CodInseeColl                           object
# VoteFormelChap                           bool
# TypProv                                 Int16
# BudgPrec                                Int16
# RefProv                                object
# ReprRes                                 Int16
# NatFonc                                 Int16
# PresentationSimplifiee                   bool
# DepFoncN2                             float64
# RecFoncN2                             float64
# DepInvN2                              float64
# RecInvN2                              float64
# CodTypBud                              object
# CodBud                                 object
# ProjetBudget                             bool
# Affect                                 object
# SpecifBudget                            Int64
# FinJur                                  Int64
# @md5                                   object
# @sha1                                  object
# dtype: object

# %%
df8['@date'] = pd.to_datetime(df8['@date'], format='ISO8601', utc= True)
df8.head()
# Out:
#    Id_Fichier          Nomenclature  Exer           Siret      Siren CodColl  \
# 0      671182              M4-M49_D  2020  25540368500027  255403685     434
# 0      815288   M14-M14_COM_SUP3500  2021  20007067000191  200070670     050
# 0      618507              M4-M49_D  2019  21350002800096  213500028     413
# 0      653656  M14-M14_COM_500_3500  2020  21560146900095  215601469     301
# 0      687838  M14-M14_COM_500_3500  2020  21430062600014  214300626     206
#
#                  LibelleColl     DteStr                            @date  \
# 0                 SDAA54 M49 2021-03-25 2021-03-25 10:17:22.986000+00:00
# 0   ZA BUDAN PLEINE-FOUGERES 2021-01-01 2022-01-31 09:57:22.066000+00:00
# 0     ASSAINISSEMENT AMANLIS 2019-01-01        2020-08-13 15:35:46+00:00
# 0  LOTISSEMENT ESPACE AMEDEE 2020-01-01        2021-02-22 16:15:27+00:00
# 0                  CHASPUZAC 2021-03-23 2021-03-25 12:42:20.421000+00:00
#
#       DteDec   DteDecEx NumDec  IdPost  \
# 0 2021-03-23 2021-03-25    NaN  054011
# 0 2021-01-01 2021-01-01    NaN  035045
# 0 2019-01-01 2019-01-01    NaN  035034
# 0 2020-01-01 2020-01-01    NaN  056038
# 0        NaT        NaT    NaN  043030
#
#                                LibellePoste  \
# 0                   Trésorerie de Maxéville
# 0             CENTRE DES FINANCES PUBLIQUES
# 0  CENTRE DES FINANCES PUBLIQUES DE RETIERS
# 0              CENTRE DES FINANCES PUBLIQUE
# 0                 TRESORERIE LE PUY-ST-JEAN
#
#                                       LibelleEtabPal       IdEtabPal  \
# 0  syndicat départemental d'assaissinissement aut...  25540368500019
# 0                 CC PAYS DOL BAIE MONT SAINT-MICHEL  20007067000019
# 0                                  COMMUNE D AMANLIS  21350002800013
# 0                                                NaN            <NA>
# 0                                                NaN            <NA>
#
#                  LibelleEtab          IdEtab NatDec NatVote  OpeEquip  \
# 0                 SDAA54 M49  25540368500027     09    FcIc     False
# 0   ZA BUDAN PLEINE-FOUGERES  20007067000191     09    FcIc      True
# 0     ASSAINISSEMENT AMANLIS  21350002800096     09    FcIc     False
# 0  LOTISSEMENT ESPACE AMEDEE  21560146900095     09    FcIc     False
# 0       COMMUNE DE CHASPUZAC  21430062600014     09    FcIc      True
#
#   CodInseeColl  VoteFormelChap  TypProv  BudgPrec RefProv  ReprRes  NatFonc  \
# 0                        False        1         2     NaN        3        1
# 0          NaN           False        1         1     NaN        3        1
# 0                        False        1         2                3        1
# 0                        False        1         2                3        1
# 0        43062           False        1         2     NaN        3        1
#
#    PresentationSimplifiee  DepFoncN2  RecFoncN2  DepInvN2  RecInvN2 CodTypBud  \
# 0                   False        0.0        0.0       0.0       0.0         A
# 0                    True        0.0        0.0       0.0       0.0         A
# 0                   False        0.0        0.0       0.0       0.0         A
# 0                   False        0.0        0.0       0.0       0.0         P
# 0                    True        NaN        NaN       NaN       NaN         P
#
#   CodBud  ProjetBudget Affect  SpecifBudget  FinJur  \
# 0     00          True    NaN          <NA>    <NA>
# 0     16         False    NaN          <NA>    <NA>
# 0     00         False                 <NA>    <NA>
# 0     00         False                 <NA>    <NA>
# 0     00         False    NaN          <NA>    <NA>
#
#                                @md5                                     @sha1
# 0  B7DFD2AD2AF730F68F6E7D65E6C77AB4  86DE552F22F3445EB85F0445A42E312B8D65F8B2
# 0  B0C9D982A0A2D619AB6131C0719D3FC9  7E2C610430F21DEF6C2DE0DFA5DFC3D3F4E84A6B
# 0  4203FB8AC4864957537E079846456939  22ABF0D1B2B3981AF017D1DD53A231E304EAC8F3
# 0  8DA2060B9C49D192BF1C95C85FFBA0C8  11BD944F301E635062355A5E88CE094505D73566
# 0  65A88195E80AB330DBC2BCA5C2932E9E  8B05CDA876A142A4264551467AA121892C254B4F

# %%
df_doc1['FinJur'].value_counts()
# Out:
# FinJur
# 910811363         2
# 9308127722        1
# 05                1
# 21590017600011    1
# 380790386         1
# Name: count, dtype: int64

# %% [markdown]
# DteDec : demande beaucoup de nettoyage mannuel, avec des années en 1300 ou 1020, mal pris pour la date
#
# NatCEPL, Departement : champ libres, poubelle
#
# Affect : 029026 ou PORNIC

# %%
chemin_20 = '../../fichiers20/todo_xml_20/'

def multi_budget(chemin_des_xml) :
 ''' Changement à faire : 
 - Enlever la liste, ne plus faire de concat
 - Faire une fonction de select dans la table 
 - Faire une fonction d'insertion dans la table
 - Voir les 7 erreurs '''  
 chemin_xml_entree_glob = glob.glob(os.path.join(chemin_des_xml, "*.gz"))
 #connection à la table
 liste_df = []

 for fichier in chemin_xml_entree_glob : 
  id_fichier = _isolement_id(fichier)
  #print(id_fichier)
  #Necessite verif dans tables
  if id_fichier is None : 
   print('vide')
   pass 
  else : 
   try : 
    #print('etape 2')
    fichier_parse = parse_fichier(fichier)
    chemin_exer = fichier_parse['DocumentBudgetaire']['Budget']['BlocBudget']['Exer']
    chemin_nomenclature = fichier_parse['DocumentBudgetaire']['Budget']['EnTeteBudget']['Nomenclature']
    dict_metadonnees = {'Id_Fichier' : id_fichier, 
                        'Nomenclature' : chemin_nomenclature.get('@V'),
                        'Exer' : chemin_exer.get('@V')}
    #print(dict_metadonnees)
    df_budget = extraction_budget(fichier_parse, dict_metadonnees)
    liste_df.append(df_budget)
    #insertion dans table
   except Exception as e : 
     print(id_fichier, 'erreur')
     print(e)
 
 df_mega = pd.concat(liste_df)
 return df_mega

# %%
der = multi_budget(chemin_20)
# Out:
# 775775 erreur
# no element found: line 1, column 0

# %%
der.head()
# Out:
#    Id_Fichier Nomenclature  Exer  TypOpBudg Operation Nature ContNat LibCpte  \
# 0      671182     M4-M49_D  2020          2       NaN    023     NaN     NaN
# 1      671182     M4-M49_D  2020       <NA>       NaN   2051     NaN     NaN
# 2      671182     M4-M49_D  2020       <NA>       NaN  21562     NaN     NaN
# 3      671182     M4-M49_D  2020       <NA>       NaN   2188     NaN     NaN
# 4      671182     M4-M49_D  2020       <NA>       NaN  60226     NaN     NaN
#
#   Fonction ContFon ArtSpe CodRD  MtBudgPrec  MtRARPrec  MtPropNouv  MtPrev  \
# 0      NaN     NaN  False     D         NaN        NaN         NaN     NaN
# 1      NaN     NaN  False     D         NaN        NaN         NaN     NaN
# 2      NaN     NaN  False     D         NaN        NaN         NaN     NaN
# 3      NaN     NaN  False     D         NaN        NaN         NaN     NaN
# 4      NaN     NaN  False     D         NaN        NaN         NaN     NaN
#
#    OpBudg  CredOuv  MtReal  MtRAR3112 ContOp OpeCpteTiers MtSup  ApVote  Brut  \
# 0    True  9800.00     NaN        0.0    NaN          NaN   NaN     NaN   NaN
# 1   False  2010.00     NaN        0.0    NaN          NaN   NaN     NaN   NaN
# 2   False  6465.32     NaN        0.0    NaN          NaN   NaN     NaN   NaN
# 3   False  5324.68     NaN        0.0    NaN          NaN   NaN     NaN   NaN
# 4   False  5000.00     NaN        0.0    NaN          NaN   NaN     NaN   NaN
#
#    BudgetHorsRAR Comp  ICNE  ICNEPrec  MtOpeCumul  MtOpeInfo  Net  ProdChaRat  \
# 0            NaN  NaN   NaN       NaN         NaN        NaN  NaN         NaN
# 1            NaN  NaN   NaN       NaN         NaN        NaN  NaN         NaN
# 2            NaN  NaN   NaN       NaN         NaN        NaN  NaN         NaN
# 3            NaN  NaN   NaN       NaN         NaN        NaN  NaN         NaN
# 4            NaN  NaN   NaN       NaN         NaN        NaN  NaN         NaN
#
#   RARPrec CaracSup  TypOpe ChapSpe ProgAutoLib ProgAutoNum VirCredNum  \
# 0     NaN      NaN    <NA>     NaN         NaN         NaN        NaN
# 1     NaN      NaN    <NA>     NaN         NaN         NaN        NaN
# 2     NaN      NaN    <NA>     NaN         NaN         NaN        NaN
# 3     NaN      NaN    <NA>     NaN         NaN         NaN        NaN
# 4     NaN      NaN    <NA>     NaN         NaN         NaN        NaN
#
#    CodeRegion Section APVote RARprec
# 0        <NA>     NaN    NaN     NaN
# 1        <NA>     NaN    NaN     NaN
# 2        <NA>     NaN    NaN     NaN
# 3        <NA>     NaN    NaN     NaN
# 4        <NA>     NaN    NaN     NaN

# %%
der['Comp'].value_counts()
# Out:
# Comp
# 0    22
# Name: count, dtype: int64

# %%
der[(~der['RARPrec'].isna()) | (~der['RARprec'].isna()) ][['Id_Fichier','RARPrec', 'RARPrec']]
# Out:
#     Id_Fichier   RARPrec   RARPrec
# 0       760357      0.00      0.00
# 1       760357      0.00      0.00
# 2       760357      0.00      0.00
# 3       760357      0.00      0.00
# 4       760357      0.00      0.00
# ..         ...       ...       ...
# 90      793145  14619.00  14619.00
# 91      793145   1600.00   1600.00
# 92      793145  49675.00  49675.00
# 93      793145   3417.00   3417.00
# 98      793145  11355.00  11355.00
#
# [214485 rows x 3 columns]

# %%
der['CodeRegion'].value_counts()
# Out:
# CodeRegion
# 1    1427
# 2     733
# 4     663
# 3     525
# 5     140
# Name: count, dtype: int64

# %%
der[~der['APVote'].isna()]
# Out:
#     Id_Fichier Nomenclature  Exer  TypOpBudg Operation  Nature ContNat  \
# 35      763528      M61-M61  2021       <NA>      2017   21578     NaN
# 41      763528      M61-M61  2021       <NA>      2017    2184     NaN
# 46      763528      M61-M61  2021       <NA>      2017  231312     NaN
# 0       801927      M57-M57  2022       <NA>    201814    2315     NaN
# 86      801927      M57-M57  2022       <NA>    202001   21838     NaN
# ..         ...          ...   ...        ...       ...     ...     ...
# 52      787082      M57-M57  2021       <NA>        48   21314     NaN
# 58      787082      M57-M57  2021       <NA>      0020    2128     NaN
# 62      787082      M57-M57  2021       <NA>        44    2313     NaN
# 40      783586      M61-M61  2021       <NA>   2021001  231312     NaN
# 67      783586      M61-M61  2021       <NA>       NaN    1317      13
#
#                                               LibCpte Fonction ContFon ArtSpe  \
# 35                            PLAN IMMO 1 - 2017_2021      NaN     NaN    NaN
# 41                            PLAN IMMO 1 - 2017_2021      NaN     NaN    NaN
# 46                            PLAN IMMO 1 - 2017_2021      NaN     NaN    NaN
# 0                        LIAISON 9 ECLUSES / ACROPOLE      518     NaN  False
# 86                        REFONTE SYSTEME INFORMATION      020     NaN  False
# ..                                                ...      ...     ...    ...
# 52             Espace culturel et associatif Gallieni      311     NaN  False
# 58        Aménagement du Parc des Coteaux - Cypressat      511     NaN  False
# 62                                               PPMS       20     NaN  False
# 40                        CONSTRUCTION DE 5 CPI TYPES      NaN     NaN    NaN
# 67  ACQUISITION D'ENGINS DANS LE CADRE DU PPE 2019...      NaN     NaN    NaN
#
#    CodRD  MtBudgPrec  MtRARPrec  MtPropNouv      MtPrev  OpBudg     CredOuv  \
# 35     D     3102.65        NaN     1412.99     1412.99   False      901.70
# 41     D    74307.15        NaN   -23700.89   -23700.89   False    60390.71
# 46     D  6399974.92        NaN -1279646.32 -1279646.32   False  3088239.24
# 0      D        0.00        0.0  6000000.00  6000000.00   False        0.00
# 86     D        0.00        0.0   500000.00   500000.00   False        0.00
# ..   ...         ...        ...         ...         ...     ...         ...
# 52     D   365000.00        0.0        0.00        0.00   False        0.00
# 58     D   150000.00        0.0        0.00        0.00   False        0.00
# 62     R        0.00        0.0        0.00        0.00   False        0.00
# 40     D   750000.00        NaN  -400000.00  -400000.00   False         NaN
# 67     R    10000.00        NaN   -10000.00   -10000.00   False    10000.00
#
#         MtReal  MtRAR3112   ContOp OpeCpteTiers  \
# 35      901.70        NaN     2017          NaN
# 41    22586.98   37803.73     2017          NaN
# 46  2699346.31   86799.82     2017          NaN
# 0         0.00       0.00   201814          NaN
# 86        0.00       0.00   202001          NaN
# ..         ...        ...      ...          ...
# 52        0.00       0.00       21          NaN
# 58        0.00       0.00       21          NaN
# 62        0.00       0.00       23          NaN
# 40         NaN        NaN  2021001          NaN
# 67         NaN        NaN      NaN          NaN
#
#                                                 MtSup  ApVote  Brut  \
# 35  [{'@Code': 'APVote', '@V': '1412.99'}, {'@Code...     NaN   NaN
# 41  [{'@Code': 'APVote', '@V': '-23700.89'}, {'@Co...     NaN   NaN
# 46  [{'@Code': 'APVote', '@V': '-1279646.32'}, {'@...     NaN   NaN
# 0   [{'@Code': 'MtOpeCumul', '@V': '3729058.92'}, ...     NaN   NaN
# 86  [{'@Code': 'MtOpeCumul', '@V': '158063.71'}, {...     NaN   NaN
# ..                                                ...     ...   ...
# 52  [{'@Code': 'APVote', '@V': '365000.00'}, {'@Co...     NaN   NaN
# 58  [{'@Code': 'APVote', '@V': '166000.00'}, {'@Co...     NaN   NaN
# 62             {'@Code': 'APVote', '@V': '121717.11'}     NaN   NaN
# 40  [{'@Code': 'APVote', '@V': '-400000.00'}, {'@C...     NaN   NaN
# 67  [{'@Code': 'APVote', '@V': '-10000.00'}, {'@Co...     NaN   NaN
#
#     BudgetHorsRAR Comp  ICNE  ICNEPrec  MtOpeCumul  MtOpeInfo  Net  \
# 35        3102.65  NaN   NaN       NaN         NaN        NaN  NaN
# 41       36503.42  NaN   NaN       NaN         NaN        NaN  NaN
# 46     6313175.10  NaN   NaN       NaN         NaN        NaN  NaN
# 0             NaN  NaN   NaN       NaN  3729058.92        NaN  NaN
# 86            NaN  NaN   NaN       NaN   158063.71        NaN  NaN
# ..            ...  ...   ...       ...         ...        ...  ...
# 52      365000.00  NaN   NaN       NaN         NaN        NaN  NaN
# 58      150000.00  NaN   NaN       NaN         NaN        NaN  NaN
# 62            NaN  NaN   NaN       NaN         NaN        NaN  NaN
# 40      750000.00  NaN   NaN       NaN         NaN        NaN  NaN
# 67       10000.00  NaN   NaN       NaN         NaN        NaN  NaN
#
#     ProdChaRat   RARPrec                                           CaracSup  \
# 35         NaN       NaN  [{'@Code': 'ProgAutoNum', '@V': '2017_2021'}, ...
# 41         NaN  37803.73  [{'@Code': 'ProgAutoNum', '@V': '2017_2021'}, ...
# 46         NaN  86799.82  [{'@Code': 'ProgAutoNum', '@V': '2017_2021'}, ...
# 0          NaN         0  [{'@Code': 'TypOpe', '@V': '1'}, {'@Code': 'Pr...
# 86         NaN         0  [{'@Code': 'TypOpe', '@V': '1'}, {'@Code': 'Pr...
# ..         ...       ...                                                ...
# 52         NaN       NaN           {'@Code': 'ProgAutoNum', '@V': '000041'}
# 58         NaN       NaN           {'@Code': 'ProgAutoNum', '@V': '000040'}
# 62         NaN       NaN           {'@Code': 'ProgAutoNum', '@V': '000034'}
# 40         NaN       NaN  [{'@Code': 'ProgAutoNum', '@V': '43'}, {'@Code...
# 67         NaN       NaN  [{'@Code': 'ProgAutoNum', '@V': '38'}, {'@Code...
#
#     TypOpe ChapSpe                                        ProgAutoLib  \
# 35       1     NaN                             PLAN IMMO1 - 2017_2021
# 41       1     NaN                             PLAN IMMO1 - 2017_2021
# 46       1     NaN                             PLAN IMMO1 - 2017_2021
# 0        1     NaN                       LIAISON 9 ECLUSES / ACROPOLE
# 86       1     NaN                        REFONTE SYSTEME INFORMATION
# ..     ...     ...                                                ...
# 52    <NA>     NaN                                                NaN
# 58    <NA>     NaN                                                NaN
# 62    <NA>     NaN                                                NaN
# 40       1     NaN                        CONSTRUCTION DE 5 CPI TYPES
# 67    <NA>     NaN  ACQUISITION D'ENGINS DANS LE CADRE DU PPE2019-...
#
#    ProgAutoNum VirCredNum  CodeRegion Section       APVote RARprec
# 35   2017_2021        NaN        <NA>     NaN      1412.99     NaN
# 41   2017_2021        NaN        <NA>     NaN    -23700.89     NaN
# 46   2017_2021        NaN        <NA>     NaN  -1279646.32     NaN
# 0       AP1801        NaN        <NA>     NaN  11623082.15     NaN
# 86      AP2001        NaN        <NA>     NaN       296000     NaN
# ..         ...        ...         ...     ...          ...     ...
# 52      000041        NaN        <NA>     NaN    365000.00     NaN
# 58      000040        NaN        <NA>     NaN    166000.00     NaN
# 62      000034        NaN        <NA>     NaN    121717.11     NaN
# 40          43        NaN        <NA>     NaN   -400000.00     NaN
# 67          38        NaN        <NA>     NaN    -10000.00     NaN
#
# [1990 rows x 44 columns]

# %%
f719853 = '../../fichiers20/todo_xml_20/760357.xml.gz'
parse_fichier(f719853)
# Out:
# {'DocumentBudgetaire': {'@xsi:schemaLocation': 'http://www.minefi.gouv.fr/cp/demat/docbudgetaire Actes_budgetaires___Schema_Annexes_Bull_V15\\DocumentBudgetaire.xsd',
#   '@xmlns': 'http://www.minefi.gouv.fr/cp/demat/docbudgetaire',
#   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'VersionSchema': {'@V': '97'},
#   'BlocEditeur': {'CodeEditeur': {'@V': 'CGI'}},
#   'VersionOutil': [{'@outil': 'DSC_COMMON', '@version': '27'},
#    {'@outil': 'REMAT', '@version': '3_2021'}],
#   'Scellement': {'@md5': 'd5a4cda10294a7e64ae7424322937871',
#    '@sha1': '8fed6ac32c38a767ba8a5c7e7ddfc27f9f50e05e',
#    '@date': '2021-05-26T09:02:18'},
#   'EnTeteDocBudgetaire': {'DteStr': {'@V': '2021-05-26'},
#    'LibellePoste': {'@V': 'La Paierie Départementale'},
#    'IdPost': {'@V': '041090'},
#    'LibelleColl': {'@V': 'Val de Loire Numérique'},
#    'IdColl': {'@V': '20004605000023'},
#    'NatCEPL': {'@V': 'Etablissements Publics'}},
#   'Budget': {'EnTeteBudget': {'LibelleEtab': {'@V': 'Val de Loire Très Haut Débit'},
#     'IdEtab': {'@V': '20004605000023'},
#     'CodColl': {'@V': '449'},
#     'CodBud': {'@V': '01'},
#     'Nomenclature': {'@V': 'M4-M4'}},
#    'BlocBudget': {'NatDec': {'@V': '02'},
#     'NumDec': {'@V': '1'},
#     'Exer': {'@V': '2021'},
#     'DteDec': {'@V': '2021-05-20'},
#     'DteDecEx': {'@V': '2021-05-20'},
#     'NatVote': {'@V': 'FcIc'},
#     'OpeEquip': {'@V': 'false'},
#     'VoteFormelChap': {'@V': 'false'},
#     'TypProv': {'@V': '1'},
#     'BudgPrec': {'@V': '1'},
#     'ReprRes': {'@V': '1'},
#     'NatFonc': {'@V': '1'},
#     'PresentationSimplifiee': {'@V': 'false'},
#     'CodTypBud': {'@V': 'A'},
#     'IdEtabPal': {'@V': '20004605000015'},
#     'LibelleEtabPal': {'@V': 'Val de Loire Numérique'}},
#    'InformationsGenerales': {'Information': [{'@Code': 'DtDelibAmort1An',
#       '@V': '0.00'},
#      {'@Code': 'EPCI', '@V': '0.00'},
#      {'@Code': 'LieuCommDoc', '@V': '0.00'},
#      {'@Code': 'MoyNatCoefMobFiscEl', '@V': '0.00'},
#      {'@Code': 'MoyNatCoefMobPotFisc', '@V': '0.0%'},
#      {'@Code': 'MoyNatDepEq', '@V': '0.00'},
#      {'@Code': 'MoyNatDepEqB', '@V': '0.0%'},
#      {'@Code': 'MoyNatDepFoncRemDette', '@V': '0.0%'},
#      {'@Code': 'MoyNatDepPers', '@V': '0.0%'},
#      {'@Code': 'MoyNatDepRFonc', '@V': '0.00'},
#      {'@Code': 'MoyNatDGFPop', '@V': '0.00'},
#      {'@Code': 'MoyNatEncDettePop', '@V': '0.00'},
#      {'@Code': 'MoyNatEncDetteRecFonc', '@V': '0.0%'},
#      {'@Code': 'MoyNatFin', '@V': '0.00'},
#      {'@Code': 'MoyNatFin4T', '@V': '0.00'},
#      {'@Code': 'MoyNatFisc', '@V': '0.00'},
#      {'@Code': 'MoyNatFiscTaxPro', '@V': '0.00'},
#      {'@Code': 'MoyNatProdImpo', '@V': '0.00'},
#      {'@Code': 'MoyNatRecRFonc', '@V': '0.00'},
#      {'@Code': 'MtAmort1An', '@V': '0.00'},
#      {'@Code': 'NbResSec', '@V': '0.00'},
#      {'@Code': 'PopTot', '@V': '0.00'},
#      {'@Code': 'PotFin', '@V': '0.00'},
#      {'@Code': 'PotFin4T', '@V': '0.00'},
#      {'@Code': 'PotFisc', '@V': '0.00'},
#      {'@Code': 'PotFisc3T', '@V': '0.00'},
#      {'@Code': 'PotFisc4T', '@V': '0.00'},
#      {'@Code': 'PotFiscTaxPro', '@V': '0.00'},
#      {'@Code': 'SourceRatio', '@V': '0.00'},
#      {'@Code': 'ValCoefMobFiscEl', '@V': '0.0%'},
#      {'@Code': 'ValCoefMobPotFisc', '@V': '0.0%'},
#      {'@Code': 'ValDepEq', '@V': '0.0%'},
#      {'@Code': 'ValDepEqB', '@V': '0.0%'},
#      {'@Code': 'ValDepFoncRemDette', '@V': '0.0%'},
#      {'@Code': 'ValDepPers', '@V': '0.0%'},
#      {'@Code': 'ValDepRFonc', '@V': '0.00'},
#      {'@Code': 'ValDGFPop', '@V': '0.00'},
#      {'@Code': 'ValEncDettePop', '@V': '0.00'},
#      {'@Code': 'ValEncDetteRecFonc', '@V': '0.0%'},
#      {'@Code': 'ValEparRFonc', '@V': '0.0%'},
#      {'@Code': 'ValHab', '@V': '0.00'},
#      {'@Code': 'ValHab3T', '@V': '0.00'},
#      {'@Code': 'ValHab4T', '@V': '0.00'},
#      {'@Code': 'ValHabTaxPro', '@V': '0.00'},
#      {'@Code': 'ValProdImpo', '@V': '0.00'},
#      {'@Code': 'ValRecRFonc'}]},
#    'LigneBudget': [{'Nature': {'@V': '001'},
#      'ContNat': {'@V': '001'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '19875202.34'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '18178836.34'},
#      'MtReal': {'@V': '18178836.34'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '19875202.34'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '002'},
#      'ContNat': {'@V': '002'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '1693174.03'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '947044.42'},
#      'MtReal': {'@V': '947044.42'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '1693174.03'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '021'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '2391867.03'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '-375.00'},
#      'MtPrev': {'@V': '-375.00'},
#      'CredOuv': {'@V': '1632379.42'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '2391867.03'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '023'},
#      'ContNat': {'@V': '042'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '2391867.03'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '-375.00'},
#      'MtPrev': {'@V': '-375.00'},
#      'CredOuv': {'@V': '1632379.42'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '2391867.03'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '1312'},
#      'ContNat': {'@V': '13'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '391800.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '1526800.00'},
#      'MtReal': {'@V': '1526800.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '391800.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '1315'},
#      'ContNat': {'@V': '13'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '1264871.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '1308991.00'},
#      'MtReal': {'@V': '1308992.50'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '1264871.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '13912'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '211422.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '160529.00'},
#      'MtReal': {'@V': '160529.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '211422.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '13913'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '553695.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '553695.00'},
#      'MtReal': {'@V': '553695.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '553695.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '13915'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '112436.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '71384.00'},
#      'MtReal': {'@V': '68813.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '112436.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '2031'},
#      'ContNat': {'@V': '20'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '600000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '610000.00'},
#      'MtReal': {'@V': '368537.50'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '600000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '2033'},
#      'ContNat': {'@V': '20'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '1213.37'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '1999.76'},
#      'MtReal': {'@V': '900.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '1213.37'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '2315'},
#      'ContNat': {'@V': '23'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '0.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '226370.00'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '0.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}],
#      'CaracSup': [{'@Code': 'ProgAutoNum', '@V': 'AP'},
#       {'@Code': 'ProgAutoLib', '@V': 'LibAP'}]},
#     {'Nature': {'@V': '2764'},
#      'ContNat': {'@V': '27'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '22645724.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '21149892.00'},
#      'MtReal': {'@V': '113815.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '22645724.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}],
#      'CaracSup': [{'@Code': 'ProgAutoNum', '@V': 'AP'},
#       {'@Code': 'ProgAutoLib', '@V': 'LibAP'}]},
#     {'Nature': {'@V': '28031'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '198912.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '125205.00'},
#      'MtReal': {'@V': '125205.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '198912.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '28033'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '1838.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '1658.00'},
#      'MtReal': {'@V': '1658.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '1838.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '28153'},
#      'ContNat': {'@V': '040'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '0.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '375.00'},
#      'MtPrev': {'@V': '375.00'},
#      'CredOuv': {'@V': '0.00'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '0.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6061'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '1000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '4500.00'},
#      'MtReal': {'@V': '1251.34'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '1000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '611'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '40000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '40000.00'},
#      'MtReal': {'@V': '51444.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '40000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '617'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '30000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '50000.00'},
#      'MtReal': {'@V': '6000.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '30000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6137'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '9000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '9000.00'},
#      'MtReal': {'@V': '8090.50'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '9000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6156'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '20000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '20000.00'},
#      'MtReal': {'@V': '27237.50'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '20000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6215'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '302100.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '264900.00'},
#      'MtReal': {'@V': '253081.18'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '302100.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6287'},
#      'ContNat': {'@V': '011'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '23000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '20000.00'},
#      'MtReal': {'@V': '19028.37'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '23000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '658'},
#      'ContNat': {'@V': '65'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '10.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '10.00'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '10.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6711'},
#      'ContNat': {'@V': '67'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '10000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '10000.00'},
#      'MtReal': {'@V': '0.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '10000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '6811'},
#      'ContNat': {'@V': '042'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtBudgPrec': {'@V': '200750.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '375.00'},
#      'MtPrev': {'@V': '375.00'},
#      'CredOuv': {'@V': '126863.00'},
#      'MtReal': {'@V': '126863.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '200750.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '757'},
#      'ContNat': {'@V': '75'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '412000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '400000.00'},
#      'MtReal': {'@V': '411998.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '412000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '774'},
#      'ContNat': {'@V': '77'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '36000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '36000.00'},
#      'MtReal': {'@V': '36000.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '36000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '777'},
#      'ContNat': {'@V': '042'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '877553.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '785608.00'},
#      'MtReal': {'@V': '783037.00'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '1'},
#      'TypOpBudg': {'@V': '2'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '877553.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]},
#     {'Nature': {'@V': '7588'},
#      'ContNat': {'@V': '75'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtBudgPrec': {'@V': '9000.00'},
#      'MtRARPrec': {'@V': '0.00'},
#      'MtPropNouv': {'@V': '0.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '9000.00'},
#      'MtReal': {'@V': '8090.50'},
#      'MtRAR3112': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': [{'@Code': 'BudgetHorsRAR', '@V': '9000.00'},
#       {'@Code': 'RARPrec', '@V': '0.00'}]}],
#    'Annexes': {'DATA_SIGNATURE': {'SIGNATURE': {'NbrMembExer': {'@V': '54'},
#       'NbrMembPresent': {'@V': '13'},
#       'NbrSuffExprime': {'@V': '27'},
#       'NbrVotePour': {'@V': '27'},
#       'NbrVoteContre': {'@V': '0'},
#       'NbrVoteAbstention': {'@V': '0'},
#       'DtConvoc': {'@V': '2021-05-11'},
#       'LibPresentPar': {'@V': 'le Président'},
#       'LibPresentLieu': {'@V': 'Blois'},
#       'DtPresent': {'@V': '2021-05-20'},
#       'LibDelibPar': {'@V': "L'assemblée délibérante"},
#       'LibReuniSession': {'@V': 'Conseil Syndical'},
#       'LibDelibLieu': {'@V': 'Blois'},
#       'DtDelib': {'@V': '2021-05-20'},
#       'DtTransmPrefect': {'@V': '2021-05-21'},
#       'DtPub': {'@V': '2021-05-25'}}},
#     'DATA_SOMMAIRE': {'SOMMAIRE': [{'CodeAnnexe': {'@V': 'PG'},
#        'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'SOM'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'I'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-B1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-B2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-A1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-A2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.3'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.4'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.5'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A3.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A3.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A4.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A4.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A5.1.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A5.1.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A5.2.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A5.2.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A7'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.3'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.4'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.5'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.7'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B2.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B2.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-C1.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-C1.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-C2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-C3'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'ARS'}, 'Present': {'@V': 'true'}}]}}}}}
