# %%
import sqlalchemy
from sqlalchemy import MetaData
from sqlalchemy.orm import sessionmaker

# %%
engine = sqlalchemy.create_engine('postgresql://verzochia:verzochia@localhost:5432/db_v1',echo=True)

# %%
metadata = MetaData()
metadata_1 = metadata.reflect(bind=engine)

# %%
TABLE_BLOC_BUDGET_QUERY = """
    CREATE TABLE Bloc_Budget (
        ID SERIAL PRIMARY KEY,
        Id_Fichier VARCHAR NOT NULL,
        Nomenclature VARCHAR,
        Exer INT,
        TypOpBudg INT,
        Operation VARCHAR,
        Nature VARCHAR,
        ContNat VARCHAR,
        LibCpte VARCHAR,
        Fonction VARCHAR,
        ContFon VARCHAR,
        ArtSpe BOOLEAN,
        CodRD VARCHAR,
        MtBudgPrec FLOAT,
        MtRARPrec FLOAT,
        MtPropNouv FLOAT,
        MtPrev FLOAT,
        OpBudg BOOLEAN,
        CredOuv FLOAT,
        MtRAR3112 FLOAT,
        MtReal FLOAT,
        ContOp VARCHAR,
        OpeCpteTiers VARCHAR,
        MtSup VARCHAR,
        MtSup.APVote FLOAT,
        MtSup.Brut FLOAT,
        MtSup.BudgetHorsRAR FLOAT,
        MtSup.Comp VARCHAR,
        MtSup.ICNE FLOAT,
        MtSup.ICNEPrec FLOAT,
        MtSup.MtOpeCumul FLOAT,
        MtSup.MtOpeInfo FLOAT,
        MtSup.Net FLOAT,
        MtSup.ProdChaRat FLOAT,
        MtSup.RARPrec FLOAT,
        CaracSup VARCHAR,
        CaracSup.TypOpe INT,
        CaracSup.Section VARCHAR,
        CaracSup.ChapSpe VARCHAR,
        CaracSup.ProgAutoLib VARCHAR,
        CaracSup.ProgAutoNum VARCHAR,
        CaracSup.VirCredNum VARCHAR,
        CaracSup.CodeRegion INT
    )"""

# %%
>>> from typing import List
>>> from typing import Optional
>>> from sqlalchemy import ForeignKey
>>> from sqlalchemy import String
from sqlalchemy import Float, Boolean
>>> from sqlalchemy.orm import DeclarativeBase
>>> from sqlalchemy.orm import Mapped
>>> from sqlalchemy.orm import mapped_column
>>> from sqlalchemy.orm import relationship

# %%
import pandas as pd

# %%
class Base(DeclarativeBase):
    pass

# %%
class BlocBudget(Base):
    __tablename__ = "BlocBudget"
    id : Mapped[int] = mapped_column(primary_key= True)
    Id_Fichier : Mapped[str] = mapped_column(String, nullable= False)
    Nomenclature : Mapped[str] 

    Exer : Mapped[str] = mapped_column(INTEGER)

    TypOpBudg : Mapped[Optional[pd.Int32Dtype]] 
    Operation : Mapped[Optional[str]]
    Nature : Mapped[Optional[str]]
    ContNat : Mapped[Optional[str]]
    LibCpte : Mapped[Optional[str]]
    Fonction : Mapped[Optional[str]]
    ContFon : Mapped[Optional[str]]
    ArtSpe : Mapped[Optional[bool]]
    CodRD : Mapped[Optional[str]]
    MtBudgPrec : Mapped[Optional[float]]
    MtRARPrec : Mapped[Optional[float]]
    MtPropNouv : Mapped[Optional[float]]
    MtPrev : Mapped[Optional[float]]
    OpBudg : Mapped[Optional[bool]]
    CredOuv : Mapped[Optional[float]]
    MtReal : Mapped[Optional[float]]
    MtRAR3112 : Mapped[Optional[float]] 
    ContOp: Mapped[Optional[str]]
    OpeCpteTiers : Mapped[Optional[str]]
    MtSup : Mapped[Optional[str]]
    MtSup_APVote : Mapped[Optional[float]]
    MtSup_Brut : Mapped[Optional[float]]
    MtSup_BudgetHorsRAR : Mapped[Optional[float]]
    MtSup_Comp : Mapped[Optional[str]]
    MtSup_ICNE : Mapped[Optional[float]]
    MtSup_ICNEPrec : Mapped[Optional[float]]
    MtSup_MtOpeCumul : Mapped[Optional[float]]
    MtSup_MtOpeInfo : Mapped[Optional[float]]
    MtSup_Net : Mapped[Optional[float]]
    MtSup_ProdChaRat : Mapped[Optional[float]]
    MtSup_RARPrec : Mapped[Optional[str]]
    CaracSup : Mapped[Optional[str]]
    CaracSup_TypOpe : Mapped[Optional[int]]
    CaracSup_Section : Mapped[Optional[str]]
    CaracSup_ChapSpe : Mapped[Optional[str]]
    CaracSup_ProgAutoLib : Mapped[Optional[str]]
    CaracSup_ProgAutoNum : Mapped[Optional[str]]
    CaracSup_VirCredNum : Mapped[Optional[str]]
    CaracSup_CodeRegion : Mapped[Optional[int]]
# Out:
# /tmp/ipykernel_31236/1527529841.py:1: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.BlocBudget, and will be replaced in the string-lookup table.
#   class BlocBudget(Base):
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 class BlocBudget(Base):
#       2     import pandas as pd
#       3     __tablename__ = "BlocBudget"
#
# File ~/projets/.venv/lib/python3.9/site-packages/sqlalchemy/orm/decl_api.py:849, in DeclarativeBase.__init_subclass__(cls, **kw)
#     847     _setup_declarative_base(cls)
#     848 else:
# --> 849     _as_declarative(cls._sa_registry, cls, cls.__dict__)
#     850 super().__init_subclass__(**kw)
#
# File ~/projets/.venv/lib/python3.9/site-packages/sqlalchemy/orm/decl_base.py:247, in _as_declarative(registry, cls, dict_)
#     242 def _as_declarative(
# ...

# %%
help(Mapped)
# Out:
# Help on class Mapped in module sqlalchemy.orm.base:
#
# class Mapped(SQLORMExpression, ORMDescriptor, _MappedAnnotationBase, sqlalchemy.sql.roles.DDLConstraintColumnRole)
#  |  Represent an ORM mapped attribute on a mapped class.
#  |
#  |  This class represents the complete descriptor interface for any class
#  |  attribute that will have been :term:`instrumented` by the ORM
#  |  :class:`_orm.Mapper` class.   Provides appropriate information to type
#  |  checkers such as pylance and mypy so that ORM-mapped attributes
#  |  are correctly typed.
#  |
#  |  The most prominent use of :class:`_orm.Mapped` is in
#  |  the :ref:`Declarative Mapping <orm_explicit_declarative_base>` form
#  |  of :class:`_orm.Mapper` configuration, where used explicitly it drives
#  |  the configuration of ORM attributes such as :func:`_orm.mapped_class`
#  |  and :func:`_orm.relationship`.
#  |
#  |  .. seealso::
#  |
#  |      :ref:`orm_explicit_declarative_base`
#  |
# ...

# %%
for table_name in metadata.tables.keys():
    print(table_name)

# %% [markdown]
# CREA TABLE

# %% [markdown]
# select into doc_budg

# %%
Session = sessionmaker(bind=engine)
session = Session()
count = session.execute(text('SELECT COUNT(*) FROM doc_budget WHERE Id_Fichier = :id_fichier'), {'id_fichier': "25"}).scalar()
count
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/projets/.venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/projets/.venv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "doc_budget" does not exist
# LINE 1: SELECT COUNT(*) FROM doc_budget WHERE Id_Fichier = '25'
#                              ^
#
# ...
