# %%
import sqlalchemy
from sqlalchemy import MetaData, text, String, Float, Boolean, ForeignKey, Select, func, Table, TIMESTAMP, DateTime
from sqlalchemy import Integer, JSON
from sqlalchemy.orm import sessionmaker, DeclarativeBase, Mapped, mapped_column, relationship
import pandas as pd 
from datetime import datetime
from typing import Optional, List 


engine = sqlalchemy.create_engine('postgresql://verzochia:verzochia@localhost:5432/db_v1')
conn = engine.connect()

metadata = MetaData()

# %%
class Base(DeclarativeBase):
    pass

class document_budgetaire(Base) :
    __tablename__ = "document_budgetaire"
    Id_Fichier : Mapped[str] = mapped_column(String, primary_key = True)

    bloc_budget : Mapped[List["bloc_budget"]] = relationship()
    data_emprunt : Mapped[List['data_emprunt']] = relationship()
    data_charge : Mapped[List['data_charge']] = relationship()
    data_concours : Mapped[List['data_concours']] = relationship()
    data_tresorerie : Mapped[List['data_tresorerie']] = relationship()
    data_tiers : Mapped[List['data_tiers']] = relationship()
    data_credit_bail : Mapped[List['data_credit_bail']] = relationship()
    data_ppp : Mapped[List['data_ppp']] = relationship()
    data_recette_affectee : Mapped[List['data_recette_affectee']] = relationship()
    data_fiscalite : Mapped[List['data_fiscalite']] = relationship()
    data_autre_engagement : Mapped[List['data_autre_engagement']] = relationship()
    data_formation : Mapped[List['data_formation']] = relationship()
    data_consolidation : Mapped[List['data_consolidation']] = relationship()
    data_organisme_eng : Mapped[List['data_organisme_eng']] = relationship()
    data_organisme_group : Mapped[List['data_organisme_group']] = relationship()
    data_patrimoine : Mapped[List['data_patrimoine']] = relationship()
    data_personnel : Mapped[List['data_personnel']] = relationship()
    data_personnel_solde : Mapped[List['data_personnel_solde']] = relationship()
    data_dette : Mapped[List['data_dette']] = relationship()
    data_ventilation : Mapped[List['data_ventilation']] = relationship()
    data_contrat_couv : Mapped[List['data_contrat_couv']] = relationship()
    data_amortissement_methode : Mapped[List['data_amortissement_methode']] = relationship()
    data_provision : Mapped[List['data_provision']] = relationship()
    data_apcp : Mapped[List['data_apcp']] = relationship()
    data_signature : Mapped[List['data_signature']] = relationship()
    data_signataire : Mapped[List['data_signataire']] = relationship()
    data_etab_service : Mapped[List['data_etab_service']] = relationship()
    data_pret : Mapped[List['data_pret']] = relationship()
    data_contrat_couv_reference : Mapped[List['data_contrat_couv_reference']] = relationship()
    service_ferroviaire_bud : Mapped[List["service_ferroviaire_bud"]] = relationship()
    service_ferroviaire_patrim : Mapped[List['service_ferroviaire_patrim']] = relationship()
    data_service_ferroviaire_ter : Mapped[List['data_service_ferroviaire_ter']] = relationship()
    data_fond_comm_hebergement : Mapped[List['data_fond_comm_hebergement']] = relationship()
    data_fond_europeen : Mapped[List['data_fond_europeen']] = relationship()
    data_fond_europeen_programmation : Mapped[List['data_fond_europeen_programmation']] = relationship()
    data_fond_aides_eco : Mapped[List['data_fond_aides_eco']] = relationship()
    data_formation_pro_jeunes : Mapped[List['data_formation_pro_jeunes']] = relationship()
    data_membresasa : Mapped[List['data_membresasa']] = relationship()
    data_flux_croises : Mapped[List['data_flux_croises']] = relationship()
    data_sommaire : Mapped[List['data_sommaire']] = relationship()

    Nomenclature : Mapped[str]
    Exer : Mapped[str] = mapped_column(Integer)  
    Siret : Mapped[Optional[str]]
    Siren : Mapped[Optional[str]]
    CodColl : Mapped[str]

    DteStr : Mapped[Optional[str]] = mapped_column(TIMESTAMP)     
    Date : Mapped[Optional[str]] = mapped_column(TIMESTAMP(timezone= True))      
    DteDec : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    DteDecEx : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    
    NumDec : Mapped[Optional[str]]
    IdPost : Mapped[Optional[str]]
    LibellePoste : Mapped[Optional[str]]
    LibelleColl : Mapped[Optional[str]]
    IdEtabPal : Mapped[Optional[str]]
    LibelleEtabPal : Mapped[Optional[str]]
    LibelleEtab : Mapped[str]
    IdEtab : Mapped[Optional[str]]
    NatDec : Mapped[str] = mapped_column(Integer)
    NatVote : Mapped[Optional[str]]
    OpeEquip : Mapped[Optional[str]] = mapped_column(Boolean)
    CodInseeColl : Mapped[Optional[str]]
    VoteFormelChap : Mapped[Optional[str]] = mapped_column(Boolean)
    TypProv : Mapped[Optional[str]] = mapped_column(Integer)
    BudgPrec : Mapped[str] = mapped_column(Integer)
    RefProv : Mapped[Optional[str]]
    ReprRes : Mapped[str] = mapped_column(Integer)
    NatFonc : Mapped[str]= mapped_column(Integer)
    PresentationSimplifiee : Mapped[Optional[str]] = mapped_column(Boolean)
    DepFoncN2 : Mapped[Optional[str]] = mapped_column(Float)
    RecFoncN2 : Mapped[Optional[str]] = mapped_column(Float)
    DepInvN2 : Mapped[Optional[str]] = mapped_column(Float)
    RecInvN2 : Mapped[Optional[str]] = mapped_column(Float)
    CodTypBud : Mapped[str]
    CodBud : Mapped[str]
    ProjetBudget : Mapped[Optional[str]] = mapped_column(Boolean)
    Affect : Mapped[Optional[str]]
    SpecifBudget : Mapped[Optional[str]] = mapped_column(Integer)
    FinJur : Mapped[Optional[str]]
    Md5 : Mapped[Optional[str]]
    Sha1 : Mapped[Optional[str]]

      
class bloc_budget(Base):
    __tablename__ = "bloc_budget"
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)
    TypOpBudg : Mapped[Optional[str]] 
    Operation : Mapped[Optional[str]]
    Nature : Mapped[Optional[str]]
    ContNat : Mapped[Optional[str]]
    LibCpte : Mapped[Optional[str]]
    Fonction : Mapped[Optional[str]]
    ContFon : Mapped[Optional[str]]
    ArtSpe : Mapped[Optional[str]] = mapped_column(Boolean)
    CodRD : Mapped[str]
    MtBudgPrec : Mapped[Optional[str]] = mapped_column(Float)
    MtRARPrec : Mapped[Optional[str]] = mapped_column(Float)
    MtPropNouv : Mapped[Optional[str]] = mapped_column(Float)
    MtPrev : Mapped[Optional[str]] = mapped_column(Float)
    OpBudg : Mapped[str]
    CredOuv : Mapped[Optional[str]] = mapped_column(Float)
    MtReal : Mapped[Optional[str]] = mapped_column(Float)
    MtRAR3112 : Mapped[Optional[str]] = mapped_column(Float)
    ContOp: Mapped[Optional[str]]
    OpeCpteTiers : Mapped[Optional[str]]

    MtSup : Mapped[Optional[str]]
    MtSup_APVote : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_Brut : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_BudgetHorsRAR : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_Comp : Mapped[Optional[str]]
    MtSup_ICNE : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_ICNEPrec : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_MtOpeCumul : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_MtOpeInfo : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_Net : Mapped[Optional[str]] = mapped_column(Float)
    MtSup_ProdChaRat : Mapped[Optional[str]]
    MtSup_RARPrec : Mapped[Optional[str]]

    CaracSup : Mapped[Optional[str]]
    CaracSup_TypOpe : Mapped[Optional[str]] = mapped_column(Integer)
    CaracSup_Section : Mapped[Optional[str]]
    CaracSup_ChapSpe : Mapped[Optional[str]]
    CaracSup_ProgAutoLib : Mapped[Optional[str]]
    CaracSup_ProgAutoNum : Mapped[Optional[str]]
    CaracSup_VirCredNum : Mapped[Optional[str]]
    CaracSup_CodeRegion : Mapped[Optional[str]] = mapped_column(Integer)

class data_emprunt(Base) : 
    __tablename__ = 'data_emprunt'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str]  = mapped_column(Integer)

    CodTypEmpr : Mapped[Optional[str]]
    CodProfilAmort : Mapped[Optional[str]]
    CodProfilAmortDtVote : Mapped[Optional[str]]
    ProfilAmort : Mapped[Optional[str]] = mapped_column(String(50))
    ProfilAmortDtVote : Mapped[Optional[str]] = mapped_column(String(50))
    CodArticle : Mapped[Optional[str]] = mapped_column(String(30))
    LibCpte : Mapped[Optional[str]] = mapped_column(String(100))
    AnEncaisse : Mapped[Optional[str]] = mapped_column(Integer)
    ObjEmpr : Mapped[Optional[str]] = mapped_column(String(100))
    MtEmprOrig : Mapped[Optional[str]] = mapped_column(Float)
    DureeRest : Mapped[Optional[str]] = mapped_column(Integer)
    DureeRestInit : Mapped[Optional[str]] = mapped_column(Integer)
    DureeRestReneg : Mapped[Optional[str]] = mapped_column(Integer)
    CodTypPreteur : Mapped[Optional[str]] 
    LibOrgaPreteur : Mapped[Optional[str]] = mapped_column(String(100))
    CodPeriodRemb : Mapped[Optional[str]]
    CodPeriodRembDtVote : Mapped[Optional[str]]
    CodPeriodRembReneg : Mapped[Optional[str]]
    CodTyptxInit : Mapped[Optional[str]]
    CodTyptxDtVote : Mapped[Optional[str]]
    IndexTxVariInit : Mapped[Optional[str]] = mapped_column(String(100))
    TxActuaInit : Mapped[Optional[str]] = mapped_column(Float)
    TxMargeInit : Mapped[Optional[str]] = mapped_column(Float)
    IndexTxVariDtVote : Mapped[Optional[str]] = mapped_column(String(100))
    TxActua : Mapped[Optional[str]] = mapped_column(Float)
    IndiceEmpr : Mapped[Optional[str]] = mapped_column(String(100))
    IndiceEmprDtVote : Mapped[Optional[str]] = mapped_column(String(100))
    MtIntExer : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalExer : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalRestDu_01_01 : Mapped[Optional[str]] = mapped_column(Float)
    MtICNE : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalRestDu_31_12 : Mapped[Optional[str]] = mapped_column(Float)
    NomBenefEmprGaranti : Mapped[Optional[str]] = mapped_column(String(100))
    CodTypEmprGaranti : Mapped[Optional[str]]
    CodNatEmpr : Mapped[Optional[str]]
    DureeAnn : Mapped[Optional[str]] = mapped_column(Float)
    TotGarEchoirExer : Mapped[Optional[str]] = mapped_column(Float)
    AnnuitNetDette : Mapped[Optional[str]] = mapped_column(Float)
    ProvGarantiEmpr : Mapped[Optional[str]] = mapped_column(Float)
    RReelFon : Mapped[Optional[str]] = mapped_column(Float)
    NumContrat : Mapped[Optional[str]] = mapped_column(String(60))
    PartGarantie : Mapped[Optional[str]] = mapped_column(Float)
    Tot1Annuite : Mapped[Optional[str]] = mapped_column(Float)
    IndSousJacent : Mapped[Optional[str]]
    IndSousJacentDtVote : Mapped[Optional[str]]
    Structure : Mapped[Optional[str]]
    StructureDtVote : Mapped[Optional[str]]

    DtSignInit : Mapped[Optional[str]] = mapped_column(TIMESTAMP) 

    DtEmission : Mapped[Optional[str]] = mapped_column(TIMESTAMP)

    Dt1RembInit : Mapped[Optional[str]] = mapped_column(TIMESTAMP) 

    Txinit : Mapped[Optional[str]] = mapped_column(Float)
    RtAnticipe : Mapped[Optional[str]] = mapped_column(Boolean)
    CoutSortie : Mapped[Optional[str]] = mapped_column(String(30))
    TypeSortie : Mapped[Optional[str]]
    MtSortie : Mapped[Optional[str]] = mapped_column(Float)
    Couverture : Mapped[Optional[str]] = mapped_column(Boolean)
    MtCouvert : Mapped[Optional[str]] = mapped_column(Float)
    MtCRDCouvert : Mapped[Optional[str]] = mapped_column(Float)
    Renegocie : Mapped[Optional[str]] = mapped_column(Boolean)
    DureeContratInit : Mapped[Optional[str]] = mapped_column(Float)
    DtPeriodeBonif : Mapped[Optional[str]] = mapped_column(String(100))
    TxMini : Mapped[Optional[str]] = mapped_column(String(100))
    TxMaxi : Mapped[Optional[str]] = mapped_column(String(100))
    TxApresCouv : Mapped[Optional[str]] = mapped_column(String(100))
    MtInt778 : Mapped[Optional[str]] = mapped_column(Float)

    DtFinContr : Mapped[Optional[str]] = mapped_column(TIMESTAMP)

    LibOrgCoContr : Mapped[Optional[str]] = mapped_column(String(100))
    TypCouv : Mapped[Optional[str]] = mapped_column(String(30))
    NatCouv : Mapped[Optional[str]] = mapped_column(String(100))
    MtCouv : Mapped[Optional[str]] = mapped_column(Float)

    DtDebCouv : Mapped[Optional[str]] = mapped_column(TIMESTAMP) 
    DtFinCouv : Mapped[Optional[str]] = mapped_column(TIMESTAMP) 

    CodTypTxCouv : Mapped[Optional[str]]
    IndiceCouv : Mapped[Optional[str]] = mapped_column(String(100))
    DtRegltCouv : Mapped[Optional[str]] = mapped_column(String(100))
    MtCommCouv : Mapped[Optional[str]] = mapped_column(Float)
    MtPrimePayeeCouv : Mapped[Optional[str]] = mapped_column(Float)
    MPrimeRecueCouv : Mapped[Optional[str]] = mapped_column(Float)
    TxPaye : Mapped[Optional[str]] = mapped_column(Float)
    TxRecu : Mapped[Optional[str]] = mapped_column(Float)
    MtCharges : Mapped[Optional[str]] = mapped_column(Float)
    MtProduits : Mapped[Optional[str]] = mapped_column(Float)
    IndSousJacentAvantCouv : Mapped[Optional[str]]
    StuctureAvantCouv : Mapped[Optional[str]]
    IndSousJacentApresCouv : Mapped[Optional[str]]
    StuctureApresCouv : Mapped[Optional[str]]

    DtReneg : Mapped[Optional[str]] = mapped_column(TIMESTAMP) 

    DureeContratReneg : Mapped[Optional[str]] = mapped_column(Integer)
    CodTypTxReneg : Mapped[Optional[str]]
    IndexTxVariReneg : Mapped[Optional[str]] = mapped_column(String(100))
    TxActuaReneg : Mapped[Optional[str]] = mapped_column(Float)
    CodProfilAmortReneg : Mapped[Optional[str]]
    MtEmprReneg : Mapped[Optional[str]] = mapped_column(Float)
    MtCRDRefin : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalReamenage : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]] = mapped_column(String(100))

#Attention, deux exer à prévoir lors de l'intégration à la db 
class data_charge(Base) :
    __tablename__ = 'data_charge'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    CodTypeCharge : Mapped[Optional[str]]
    Exer_annexe : Mapped[str] = mapped_column(Integer)
    NatDepTransf : Mapped[str]
    DureeEtal : Mapped[str] = mapped_column(Integer)
    DtDelib : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    MtDepTransf : Mapped[str] = mapped_column(Float)
    MtAmort : Mapped[str] = mapped_column(Float)
    MtDotAmort : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

#Mettre en accord le schéma sur l'ordre des colonnes 
class data_concours(Base) : 
    __tablename__ = 'data_concours'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    CodArticle : Mapped[Optional[str]]
    CodInvFonc : Mapped[Optional[str]]
    CodNatJurBenefCA : Mapped[Optional[str]]
    LibOrgaBenef : Mapped[str]
    MtSubv : Mapped[str] = mapped_column(Float)
    LibPrestaNat : Mapped[Optional[str]]
    DenomOuNumSubv : Mapped[Optional[str]]
    ObjSubv : Mapped[Optional[str]]
    Siret : Mapped[Optional[str]]
    PopCommune : Mapped[Optional[str]] = mapped_column(Integer)
    Champ_Editeur : Mapped[Optional[str]]

class data_tresorerie(Base) : 
    __tablename__ = 'data_tresorerie'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    CodArticle : Mapped[str]
    LibOrgaPret : Mapped[str]
    DtDec : Mapped[str] = mapped_column(TIMESTAMP)
    MtMaxAutori : Mapped[str] = mapped_column(Float)
    MtTirage : Mapped[str] = mapped_column(Float)
    MtRemb : Mapped[str] = mapped_column(Float)
    MtRestDu : Mapped[Optional[str]] = mapped_column(Float)
    IntManda : Mapped[Optional[str]] = mapped_column(Float)
    NumContrat : Mapped[Optional[str]]
    MtRembInt : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_tiers(Base) : 
    __tablename__ = 'data_tiers'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    CodOper : Mapped[str] = mapped_column(Integer)
    LibOper : Mapped[str]
    DtDelib : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    CodRD : Mapped[str]
    CodChapitre : Mapped[str]
    CodOperR : Mapped[Optional[str]]
    NatTrav : Mapped[Optional[str]]
    TypOpDep : Mapped[Optional[str]]
    MtRealCumulPrec : Mapped[Optional[str]] = mapped_column(Float)
    MtCredOuv : Mapped[str] = mapped_column(Float)
    MtRealExer : Mapped[str] = mapped_column(Float)
    RAR : Mapped[Optional[str]] = mapped_column(Float)
    MtCumulReal : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_credit_bail(Base) : 
    __tablename__ = 'data_credit_bail'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    ExerContr : Mapped[str] = mapped_column(Integer)
    CodTypContr : Mapped[str]
    NatBienContr : Mapped[str]
    MtRedevExer : Mapped[str] = mapped_column(Float)
    LibCredBail : Mapped[str]
    DureeContr : Mapped[str] = mapped_column(Integer)
    MtRedevN_1 : Mapped[Optional[str]] = mapped_column(Float)
    MtRedevN_2 : Mapped[Optional[str]] = mapped_column(Float)
    MtRedevN_3 : Mapped[Optional[str]] = mapped_column(Float)
    MtRedevN_4 : Mapped[Optional[str]] = mapped_column(Float)
    MtRedevN_5 : Mapped[Optional[str]] = mapped_column(Float)
    MtCumulRest : Mapped[Optional[str]] = mapped_column(Float)
    NumContr : Mapped[Optional[str]] = mapped_column(Integer)
    Champ_Editeur : Mapped[Optional[str]]

class data_ppp(Base) : 
    __tablename__ = 'data_ppp'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer)  

    LibContr : Mapped[str] 
    AnnSignContr : Mapped[str] = mapped_column(Integer) 
    NomOrgaContr : Mapped[str] 
    NatPrestaContr : Mapped[Optional[str]] 
    MtTotContr : Mapped[str] = mapped_column(Float) 
    MtRemunCoContr : Mapped[str] = mapped_column(Float) 
    DureeContr : Mapped[str] = mapped_column(Integer) 
    DtFinContr : Mapped[str] = mapped_column(TIMESTAMP) 
    PartInvest : Mapped[Optional[str]] = mapped_column(Float) 
    PartNetteInvest : Mapped[Optional[str]] = mapped_column(Float) 
    Champ_Editeur : Mapped[Optional[str]] = mapped_column(Float)

class data_recette_affectee(Base) :  
    __tablename__ = 'data_recette_affectee'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodRAffect : Mapped[str] 
    LibRAffect : Mapped[str] 
    CodChapitre : Mapped[Optional[str]] 
    CodArticle : Mapped[str] 
    LibArticle : Mapped[str] 
    MtRAE0101 : Mapped[str] = mapped_column(Float) 
    MtR : Mapped[str] = mapped_column(Float) 
    MtD : Mapped[str] = mapped_column(Float) 
    Champ_Editeur : Mapped[Optional[str]]

class data_fiscalite(Base) :   
    __tablename__ = 'data_fiscalite'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypContrib : Mapped[str] 
    CodSousTypContrib : Mapped[str]
    CodTypeCarburant : Mapped[Optional[str]]
    LibTaxe : Mapped[Optional[str]]
    MtBaseNotif : Mapped[Optional[str]] = mapped_column(Float)
    TxVariBase : Mapped[Optional[str]] = mapped_column(Float)
    TxApplicConsMunic : Mapped[Optional[str]] = mapped_column(Float)
    TxVariTx : Mapped[Optional[str]] = mapped_column(Float)
    MtProdVote : Mapped[Optional[str]] = mapped_column(Float)
    TxVariProd : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]
    Origine : Mapped[Optional[str]]
    Unite : Mapped[Optional[str]]

class data_autre_engagement(Base) :    
    __tablename__ = 'data_autre_engagement'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypAutEng : Mapped[str] 
    CodArticle : Mapped[str]
    CodTypPersoMorale : Mapped[Optional[str]]
    AnnOrig : Mapped[str] = mapped_column(Integer)
    NatEng : Mapped[str]
    NomOrgaBenef : Mapped[str]
    DureeEng : Mapped[str] = mapped_column(Integer)
    CodePeriod : Mapped[str]
    MtDetteOrig : Mapped[str] = mapped_column(Float)
    MtDette : Mapped[str] = mapped_column(Float)
    MtAnnuit : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_formation(Base) :     
    __tablename__ = 'data_formation'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier))
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    NomElu : Mapped[str]
    ActionFinanc : Mapped[str]
    Champ_Editeur : Mapped[Optional[str]]

class data_consolidation(Base) :     
    __tablename__ = 'data_consolidation'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypBudAgreg : Mapped[str]
    CodBudAnnex : Mapped[Optional[str]]
    LibBudAnnex : Mapped[Optional[str]]
    CodInvFonc : Mapped[str]
    CodRD : Mapped[str]
    MtCredOuv : Mapped[str] = mapped_column(Float)
    MtRealMandatTitre : Mapped[str] = mapped_column(Float)
    RAR : Mapped[str] = mapped_column(Float)
    SiretBudAnnexe : Mapped[Optional[str]]
    Champ_Editeur : Mapped[Optional[str]]

class data_organisme_eng(Base) :     
    __tablename__ = 'data_organisme_eng'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodNatEng : Mapped[str]
    DtEng : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    NatEng : Mapped[Optional[str]]
    NomOrgEng : Mapped[str]
    RSOrgEng : Mapped[Optional[str]]
    NatJurOrgEng : Mapped[Optional[str]]
    MtOrgEng : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]
    
class data_organisme_group(Base) :      
    __tablename__ = 'data_organisme_group'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodNatOrgGroup : Mapped[str]
    NomOrgGroup : Mapped[str]
    DtAdhGroup : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    CodModFinanc : Mapped[Optional[str]]
    MtFinancOrgGroup  : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]
    
class data_patrimoine(Base) :      
    __tablename__ = 'data_patrimoine'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodVariPatrim : Mapped[str] 
    CodEntreeSorti : Mapped[Optional[str]]
    CodModalAcqui : Mapped[Optional[str]]
    CodModalSorti : Mapped[Optional[str]]
    CodTypImmo : Mapped[Optional[str]]
    LibBien : Mapped[str] 
    MtValAcquiBien : Mapped[str] = mapped_column(Float) 
    MtCumulAmortBien : Mapped[Optional[str]] = mapped_column(Float)
    MtAmortExer: Mapped[Optional[str]] = mapped_column(Float)
    DureeAmortBien : Mapped[Optional[str]] = mapped_column(Integer)
    NumInventaire : Mapped[Optional[str]]
    DtAcquiBien : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    MtVNCBien0101 : Mapped[Optional[str]] = mapped_column(Float)
    MtVNCBien3112 : Mapped[Optional[str]] = mapped_column(Float)
    MtVNCBienSorti : Mapped[Optional[str]] = mapped_column(Float)
    MtPrixCessBienSorti : Mapped[Optional[str]] = mapped_column(Float)
    DtCessBienSorti: Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    CodTypTitre : Mapped[Optional[str]]
    LibOrgPrisePartic : Mapped[Optional[str]]
    DtDelib : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    LibObserv : Mapped[Optional[str]]
    Champ_Editeur : Mapped[Optional[str]]

class data_personnel(Base) :      
    __tablename__ = 'data_personnel'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypAgent : Mapped[Optional[str]]
    EmploiGradeAgent : Mapped[Optional[str]]
    CodCatAgent : Mapped[Optional[str]]
    TempsComplet : Mapped[Optional[str]] = mapped_column(Boolean)
    Permanent : Mapped[Optional[str]] = mapped_column(Boolean)
    NatureContrat : Mapped[Optional[str]]
    LibelleNatureContrat : Mapped[Optional[str]]
    CodSectAgentTitulaire : Mapped[Optional[str]]
    CodSectAgentNonTitulaire : Mapped[Optional[str]]
    RemunAgent : Mapped[Optional[str]] = mapped_column(Float)
    MtPrev6215: Mapped[Optional[str]] = mapped_column(Float)
    IndiceAgent : Mapped[Optional[str]]
    CodMotifContrAgent : Mapped[Optional[str]]
    LibMotifContrAgent : Mapped[Optional[str]]
    EffectifBud : Mapped[Optional[str]] = mapped_column(Float)
    EffectifPourvu : Mapped[Optional[str]] = mapped_column(Float)
    EffectifTNC : Mapped[Optional[str]] = mapped_column(Integer)
    Champ_Editeur : Mapped[Optional[str]]
    
class data_personnel_solde(Base) :      
    __tablename__ = 'data_personnel_solde'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    NbrCreatEmploi : Mapped[Optional[str]] = mapped_column(Float)
    NbrSupprEmploi : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]
    
class data_dette(Base) :      
    __tablename__ = 'data_dette'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    LibTypDette : Mapped[str] 
    MtInitDette : Mapped[str] = mapped_column(Float) 
    MtDExerDette  : Mapped[str] = mapped_column(Float) 
    MtRestDette  : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]
       
class data_ventilation(Base) :      
    __tablename__ = 'data_ventilation'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypVentil : Mapped[str]
    NomService : Mapped[Optional[str]]
    CodInvFonc : Mapped[str]
    CodRD : Mapped[str]
    TypOpBudg : Mapped[str]
    CodRegroup : Mapped[Optional[str]]
    CodChapitre : Mapped[Optional[str]]
    CodArticle : Mapped[str]
    LibCpte : Mapped[str]
    MtVentil : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_contrat_couv(Base) :      
    __tablename__ = 'data_contrat_couv'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypTx : Mapped[Optional[str]]
    NumContratCouv : Mapped[Optional[str]]
    CodTypRisqFinanc : Mapped[Optional[str]]
    NbEmpruntCouv: Mapped[Optional[str]] = mapped_column(Integer)
    LibEmprCouv : Mapped[Optional[str]]
    MtEmprCouv : Mapped[str] = mapped_column(Float)
    CapitalRestDu : Mapped[Optional[str]] = mapped_column(Float)
    DtFinContrEmpr : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    TypCouv : Mapped[Optional[str]]
    NatContrCouv : Mapped[str]
    LibOrgCoContr : Mapped[str]
    DtDebContr : Mapped[str] = mapped_column(TIMESTAMP)
    DtFinCouv : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    CodPeriodRemb : Mapped[Optional[str]]
    MtCommDiv : Mapped[Optional[str]] = mapped_column(Float)
    MtPrimePayee : Mapped[Optional[str]] = mapped_column(Float)
    MtPrimeRecue : Mapped[Optional[str]] = mapped_column(Float)
    IndexTxPaye : Mapped[Optional[str]]
    TxTxPaye : Mapped[Optional[str]] = mapped_column(Float)
    IndexTxRecu : Mapped[Optional[str]]
    TxTxRecu : Mapped[Optional[str]] = mapped_column(Float)
    StuctureAvantCouv : Mapped[Optional[str]]
    StuctureApresCouv : Mapped[Optional[str]]
    IndSousJacentAvantCouv : Mapped[Optional[str]]
    IndSousJacentApresCouv : Mapped[Optional[str]]
    MtChaOrig : Mapped[Optional[str]] = mapped_column(Float)
    MtProdOrig : Mapped[Optional[str]] = mapped_column(Float)
    DureeContr : Mapped[Optional[str]] = mapped_column(Integer)
    DtReglt : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    MtMaxAutori_N : Mapped[Optional[str]] = mapped_column(Float)
    MtMaxAutoriEmprEnc_N : Mapped[Optional[str]] = mapped_column(Float)
    MtChaOrigPrimeAss : Mapped[Optional[str]] = mapped_column(Float)
    MtChaOrigPrimeCommi : Mapped[Optional[str]] = mapped_column(Float)
    MtPert : Mapped[Optional[str]] = mapped_column(Float)
    MtProf : Mapped[Optional[str]] = mapped_column(Float)
    MtPertProf : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_amortissement_methode(Base) :      
    __tablename__ = 'data_amortissement_methode'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    LibBienAmort : Mapped[str]
    DureeBienAmort : Mapped[str] = mapped_column(Integer)
    DtDelib : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    ProcAmort : Mapped[Optional[str]]
    Champ_Editeur : Mapped[Optional[str]]

class data_provision(Base) :      
    __tablename__ = 'data_provision'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypTabProv : Mapped[str]
    CodTypProv : Mapped[Optional[str]]
    CodSTypProv : Mapped[str]
    LibNatProv : Mapped[Optional[str]]
    MtProvExer : Mapped[Optional[str]] = mapped_column(Float)
    DtConstitProv : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    MtProvConstit_01_01_N : Mapped[Optional[str]] = mapped_column(Float)
    MtProvRepr : Mapped[str] = mapped_column(Float)
    LibObjProv : Mapped[str]
    MtTotalProvAConstit : Mapped[Optional[str]] = mapped_column(Float)
    DureeEtal : Mapped[Optional[str]] = mapped_column(Integer)
    CodNatProv : Mapped[Optional[str]]
    Champ_Editeur : Mapped[Optional[str]]

class data_apcp(Base) :       
    __tablename__ = 'data_apcp'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypAutori : Mapped[str] 
    CodSTypAutori : Mapped[str] 
    NumAutori : Mapped[Optional[str]] 
    LibAutori : Mapped[Optional[str]] 
    Chapitre : Mapped[Optional[str]] 
    MtAutoriPrec : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutori_NMoins1 : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriPropose : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriVote : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriDispoAffectation : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriNonCouvParCP_01_01_N : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriAffectee : Mapped[Optional[str]] = mapped_column(Float) 
    MtAutoriAffecteeAnnulee : Mapped[Optional[str]] = mapped_column(Float) 
    MtCPAnt : Mapped[Optional[str]] = mapped_column(Float) 
    MtCPOuv : Mapped[Optional[str]] = mapped_column(Float) 
    MtCPReal : Mapped[Optional[str]] = mapped_column(Float) 
    MtCredAFinanc_NPlus1 : Mapped[Optional[str]] = mapped_column(Float) 
    MtCredAFinanc_Sup_N : Mapped[Optional[str]] = mapped_column(Float) 
    MtCredAFinanc_Sup_NPlus1 : Mapped[Optional[str]] = mapped_column(Float) 
    RatioCouvAutoriAffect_N : Mapped[Optional[str]] = mapped_column(Float) 
    RatioCouvAutoriAffect_NMoins1 : Mapped[Optional[str]] = mapped_column(Float) 
    RatioCouvAutoriAffect_NMoins2 : Mapped[Optional[str]] = mapped_column(Float) 
    RatioCouvAutoriAffect_NMoins3: Mapped[Optional[str]] = mapped_column(Float) 
    Champ_Editeur : Mapped[Optional[str]] 
    TypeChapitre : Mapped[Optional[str]] 

class data_signature(Base) :       
    __tablename__ = 'data_signature'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    NbrMembExer : Mapped[str] = mapped_column(Integer)
    NbrMembPresent : Mapped[str] = mapped_column(Integer)
    NbrSuffExprime : Mapped[str] = mapped_column(Integer)
    NbrVotePour : Mapped[str] = mapped_column(Integer)
    NbrVoteContre : Mapped[str] = mapped_column(Integer)
    NbrVoteAbstention : Mapped[str] = mapped_column(Integer)
    DtConvoc : Mapped[str] = mapped_column(TIMESTAMP)
    LibPresentPar : Mapped[Optional[str]]
    LibPresentLieu : Mapped[str]
    DtPresent : Mapped[str] = mapped_column(TIMESTAMP)
    LibDelibPar : Mapped[str]
    LibReuniSession : Mapped[Optional[str]]
    LibDelibLieu : Mapped[str]
    DtDelib : Mapped[str] = mapped_column(TIMESTAMP)
    DtTransmPrefect : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    DtPub : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    LibFin : Mapped[Optional[str]]
    DtfFin : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    Champ_Editeur : Mapped[Optional[str]]

class data_signataire(Base) :       
    __tablename__ = 'data_signataire'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    Signataire : Mapped[str]

class data_etab_service(Base) :       
    __tablename__ = 'data_etab_service'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodNatEtab : Mapped[str] 
    LibCatEtab : Mapped[Optional[str]]
    LibEtab : Mapped[str] 
    SiretEtab : Mapped[Optional[str]]
    DtCreatEtab : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    NumDelibEtab : Mapped[Optional[str]]
    DtDelibEtab : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    LibNatActivEtab : Mapped[Optional[str]]
    IndicTVAEtab : Mapped[Optional[str]] = mapped_column(Boolean)
    Champ_Editeur : Mapped[Optional[str]]
     
class data_pret(Base) :       
    __tablename__ = 'data_pret'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypPret : Mapped[str] 
    NomBenefPret  : Mapped[str] 
    DtDelib : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    MtCapitalRestDu_01_01 : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalRestDu_31_12 : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalExer : Mapped[Optional[str]] = mapped_column(Float)
    MtIntExer : Mapped[Optional[str]] = mapped_column(Float)
    MtICNE : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_contrat_couv_reference(Base) :       
    __tablename__ = 'data_contrat_couv_reference'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    NumContr : Mapped[str]
    NumContratEmprunt : Mapped[Optional[str]]
    MtEmprOrig : Mapped[Optional[str]] = mapped_column(Float)
    DureeAnn : Mapped[Optional[str]] = mapped_column(Integer)
    CodTyptxInit : Mapped[Optional[str]]
    TxActuaInit : Mapped[Optional[str]] = mapped_column(Float)
    IndexTxVariInit : Mapped[Optional[str]]
    CodProfilAmort : Mapped[Optional[str]]
    DtDebEcheance : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    LibObserv : Mapped[Optional[str]]
    MtCapitalRestDu_01_01 : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalRestDu_31_12 : Mapped[Optional[str]] = mapped_column(Float)
    MtCapitalExer : Mapped[Optional[str]] = mapped_column(Float)
    MtIntExer : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class service_ferroviaire_bud(Base) :       
    __tablename__ = 'service_ferroviaire_bud'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    
    Exer : Mapped[str] = mapped_column(Integer) 
    
    CodRD : Mapped[str]
    CodInvFonc : Mapped[str]
    CodRegroupBudFerrov : Mapped[str]
    CodChapitre : Mapped[str]
    MtVentil : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class service_ferroviaire_patrim(Base) :       
    __tablename__ = 'service_ferroviaire_patrim'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    LibRame : Mapped[str]
    Matricule : Mapped[str]
    DtMiseService : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    DtFinPot : Mapped[str] = mapped_column(TIMESTAMP)
    LibProprietaire : Mapped[str]
    LibModeFinanc : Mapped[Optional[str]]
    MtValOrig : Mapped[str] = mapped_column(Float)
    MtAmort : Mapped[Optional[str]] = mapped_column(Float)
    MtVNC : Mapped[Optional[str]] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]  

class data_service_ferroviaire_ter(Base) :       
    __tablename__ = 'data_service_ferroviaire_ter'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    CodCptTER : Mapped[str]
    MtCptTER : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_fond_comm_hebergement(Base) :       
    __tablename__ = 'data_fond_comm_hebergement'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    CodOper : Mapped[str] = mapped_column(Integer)
    LibFondHeberg : Mapped[str]
    CodRD : Mapped[str]
    LibEtabHeberg : Mapped[str]
    MtFond : Mapped[str] = mapped_column(Float)
    LibObjFond : Mapped[Optional[str]]
    Champ_Editeur : Mapped[Optional[str]]

class data_fond_europeen(Base) :       
    __tablename__ = 'data_fond_europeen'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    LibFondsEuropeen : Mapped[str] 
    CodDestFonds : Mapped[str] 
    CodRDDJust : Mapped[str] 
    LibMesure : Mapped[str] 
    CodArticle : Mapped[str] 
    MtFond : Mapped[str] = mapped_column(Float) 
    LibBenef : Mapped[Optional[str]]
    LibOper : Mapped[Optional[str]]
    LibEmetteurs : Mapped[Optional[str]]
    DtAcquit : Mapped[Optional[str]] = mapped_column(TIMESTAMP)
    Champ_Editeur : Mapped[Optional[str]]

class data_fond_europeen_programmation(Base) :       
    __tablename__ = 'data_fond_europeen_programmation'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    Programmation : Mapped[str]
    TypeGestion : Mapped[str] 
    TypeFonds : Mapped[str] 
    CodRD : Mapped[Optional[str]]
    RappelTotal : Mapped[Optional[str]] = mapped_column(Float)
    MontantN_X : Mapped[Optional[str]] = mapped_column(Float)
    MontantN : Mapped[Optional[str]] = mapped_column(Float)
    RegulN : Mapped[Optional[str]] = mapped_column(Float)
    Avances : Mapped[Optional[str]] = mapped_column(Float) 

class data_fond_aides_eco(Base) :        
    __tablename__ = 'data_fond_aides_eco'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 
    
    LibOrgConvent : Mapped[Optional[str]]
    DtConvent : Mapped[str] = mapped_column(TIMESTAMP)
    CodRD : Mapped[str]
    CodInvFon : Mapped[str]
    DtVers : Mapped[str] = mapped_column(TIMESTAMP)
    MtReliquatCPAnt : Mapped[str] = mapped_column(Float)
    MtVersExer : Mapped[str] = mapped_column(Float)
    CodArticle : Mapped[str]
    MtTotAide : Mapped[str] = mapped_column(Float)
    LibBenef : Mapped[Optional[str]]
    LibAide : Mapped[Optional[str]]
    LibFormeAide : Mapped[Optional[str]]
    MtDExerAnt : Mapped[str] = mapped_column(Float)
    MtDExer : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_formation_pro_jeunes(Base) :        
    __tablename__ = 'data_formation_pro_jeunes'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodRDTot : Mapped[str]
    CodRessExt : Mapped[Optional[str]]
    CodApprent : Mapped[str]
    MtFormN : Mapped[str] = mapped_column(Float)
    MtFormN_1 : Mapped[str] = mapped_column(Float)
    Champ_Editeur : Mapped[Optional[str]]

class data_membresasa(Base) :        
    __tablename__ = 'data_membresasa'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    Commune : Mapped[str] 
    Proprietaire : Mapped[str] 
    Superficie : Mapped[str] = mapped_column(Float)

class data_flux_croises(Base) :        
    __tablename__ = 'data_flux_croises'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodTypFlux : Mapped[str] 
    CodInvFonc : Mapped[str] 
    CodRD : Mapped[str] 
    MtCredOuv : Mapped[str] = mapped_column(Float) 
    MtReal : Mapped[str] = mapped_column(Float) 
    MtRAR : Mapped[str] = mapped_column(Float) 

class data_sommaire(Base) :        
    __tablename__ = 'data_sommaire'
    id : Mapped[int] = mapped_column(primary_key = True)
    Id_Fichier : Mapped[str] = mapped_column(ForeignKey(document_budgetaire.Id_Fichier)) 
    Nomenclature : Mapped[str] 
    Exer : Mapped[str] = mapped_column(Integer) 

    CodeAnnexe : Mapped[str]
    Present : Mapped[str] = mapped_column(Boolean)
    Champ_Editeur : Mapped[Optional[str]]

# %%
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)
