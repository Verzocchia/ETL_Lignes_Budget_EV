# %%
import gzip 
from lxml import etree
import pandas as pd 
import xmltodict
import glob
import os 
import time 
import polars as pl 
import duckdb
import shutil 

def timtim(fonction):
    def wrapper(*args, **kwargs):
        debut = time.time()
        resultat = fonction(*args, **kwargs)
        fin = time.time()
        temps_execution = fin - debut
        print(f"La fonction {fonction.__name__} a pris {temps_execution:.5f} secondes pour s'exécuter.")
        return resultat
    return wrapper

def parse_fichier(chemin) : 
 '''Ouvre et parse le fichier gzip'''
 with gzip.open(chemin, 'rb') as fichier_ouvert : 
  fichier_xml_gzip = fichier_ouvert.read()
  fichier_xml = fichier_xml_gzip.decode('latin-1')
  fichier_dict = xmltodict.parse(fichier_xml)
 return fichier_dict

def recherche_id_fichier(chemin_parquet) :
 conduck = duckdb.connect(database=':memory:', read_only=False)
 docubudg_t = conduck.read_parquet(chemin_parquet)
 requete_duckdb = ''' 
 SELECT
    DISTINCT Id_Fichier
 FROM 
    docubudg_t
 '''
 result_requete= conduck.execute(requete_duckdb).fetchdf()
 liste_id = result_requete['Id_Fichier'].to_list()
 conduck.close()
 return liste_id


def _isolement_id(fichier) : 
 '''Extrait l'id du nom du fichier pour la liste comprehension de securité

 ATTENTION, le premier split / va changer si on l'applique sur du minio '''
 val_id_fichier_source = fichier.split("\\")[-1].split('.')[0]
 if '-' in val_id_fichier_source : 
  val_id_fichier = val_id_fichier_source.split('-')[1]
 else : 
  val_id_fichier= val_id_fichier_source
 return val_id_fichier

# %% [markdown]
# Test extraction xml to parquet

# %%
DOSSIER_500 = "./fichiers/todo_xml/test1000/t500/"
DOSSIER_TODO = './fichiers/todo_xml/'
DOSSIER_PARQUET_UNITAIRE = './fichiers/todo_parquet/'

# %%
@timtim
def Extraction_xml_to_parquet(chemin) : 
 ''' Traite les XML et les envoies sous format parquet, nettoyage necessaire pour être sous forme de parquet'''
 for fichier in glob.glob(os.path.join(chemin, "*.gz")) : 
  try : 
   id_fichier = _isolement_id(fichier)
   dico = parse_fichier(fichier)
   metadonnees = dico['DocumentBudgetaire']['EnTeteDocBudgetaire']
   metadonnees['Id_Fichier'] = {'@V' : id_fichier}
   docbase = dico['DocumentBudgetaire']['Budget']['LigneBudget']
   for i in docbase : 
      i.update(metadonnees)
   df_methode_2 = pd.DataFrame(docbase)
   df_methode_2['MtSup'] = df_methode_2['MtSup'].astype(str)
   df_methode_2['CaracSup'] = df_methode_2['CaracSup'].astype(str)
   df_methode_2 = df_methode_2.reset_index(drop=True)
   df_methode_2.to_parquet(f'./fichiers/todo_parquet/{id_fichier}', engine='pyarrow')
   #shutil.move(fichier, './fichiers/done_xml/')
  except Exception as e : 
    print(f'Erreur fichier {fichier}, extraction impossible')
    #shutil.move(fichier, './fichiers/todo_xml/error/')
    print(e)
    continue

# %%
chemin_test_xml_solo = './fichiers/todo_xml/test1000/t500/616146.xml.gz'

# %%
Extraction_xml_to_parquet(DOSSIER_500)
# Out:
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612023.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612058.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612069.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612128.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612136.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612151.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612160.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612180.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612223.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612240.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612245.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612262.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612271.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612292.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612295.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612328.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612339.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612350.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612370.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612415.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612482.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612529.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612633.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612664.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612680.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612690.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612711.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612760.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612787.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612821.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612826.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612847.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612883.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612908.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612923.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612984.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\612987.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613011.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613012.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613029.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613088.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613143.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613182.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613291.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613298.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613339.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613362.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613379.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613408.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613410.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613437.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613483.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613485.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613517.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613535.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613602.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613605.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613617.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613633.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613781.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613804.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613837.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613853.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613859.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613879.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613919.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613922.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613926.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613933.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613938.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613947.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613950.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613953.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613960.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\613994.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614008.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614009.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614085.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614087.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614092.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614093.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614107.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614157.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614161.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614162.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614174.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614233.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614238.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614244.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614264.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614315.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614338.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614349.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614384.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614387.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614400.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614434.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614451.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614454.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614461.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614462.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614463.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614484.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614498.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614515.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614517.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614522.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614556.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614561.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614574.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614599.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614604.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614651.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614660.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614666.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614687.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614772.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614775.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614819.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614834.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614835.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614844.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614916.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614929.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614959.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\614995.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615018.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615019.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615037.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615043.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615045.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615055.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615066.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615107.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615188.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615193.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615204.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615225.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615248.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615273.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615302.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615306.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615352.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615355.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615379.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615396.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615408.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615412.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615414.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615417.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615433.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615434.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615439.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615450.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615459.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615493.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615506.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615554.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615694.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615726.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615753.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615759.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615767.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615881.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615882.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\615890.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616008.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616030.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616039.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616041.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616049.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616055.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616078.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616124.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616146.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616148.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616149.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616154.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616179.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616230.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616289.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616355.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616436.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616445.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616447.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616448.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616454.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616462.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616473.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616475.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616476.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616477.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616482.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616505.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616539.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616581.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616601.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616659.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616660.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616666.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616680.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616731.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616758.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616796.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616825.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616844.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616948.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616973.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616976.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\616997.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617029.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617095.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617144.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617217.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617227.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617230.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617254.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617267.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617370.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617410.xml.gz, extraction impossible
# 'CaracSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617421.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617446.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617494.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617516.xml.gz, extraction impossible
# 'MtSup'
# Erreur fichier ./fichiers/todo_xml/test1000/t500\617536.xml.gz, extraction impossible
# 'CaracSup'
# La fonction Extraction_xml_to_parquet a pris 16.70620 secondes pour s'exécuter.

# %% [markdown]
# Très bien, comme d'hab c'est MtSup et CaracSup qui posent problème, ALED. Exploration individuelle

# %%
Extraction_xml_to_parquet(chemin_test_xml_solo)
# Out:
# La fonction Extraction_xml_to_parquet a pris 0.00000 secondes pour s'exécuter.

# %% [markdown]
# Ca ne s'execute pas.. on va fouiller
# Merci isolement_id qui fait des choses bizarres, dans le doute on va vérifier sur 500

# %%
id_616146 = _isolement_id(chemin_test_xml_solo)
id_616146
# Out:
# ''

# %%
liste_id_verif_500 = []
for id_test in glob.glob(os.path.join(DOSSIER_500, "*.gz")) : 
 verif_id = _isolement_id(id_test)
 liste_id_verif_500.append(verif_id)

# %% [markdown]
# Ici c'est propre. Isolement ne fonctionne donc pas sur du pure unitaire, on va bricoler en attendant c'est pas le coeur du problème

# %%
liste_id_verif_500
# Out:
# ['612019',
#  '612023',
#  '612027',
#  '612030',
#  '612038',
#  '612050',
#  '612057',
#  '612058',
#  '612069',
#  '612078',
#  '616738',
#  '616758',
#  '616768',
#  '616790',
#  '616794',
#  '616796',
#  '616802',
#  '616818',
#  '616825',
#  '616844',
#  '616849',
#  '616885',
#  '616916',
#  '616930',
#  '616932',
#  '616943',
#  '616946',
#  '616948',
#  '616973',
#  '616976',
#  '616997',
#  '617029',
#  '617034',
#  '617084',
#  '617092',
#  '617093',
#  '617095',
#  '617107',
#  '617116',
#  '617144',
#  '617151',
#  '617158',
#  '617166',
#  '617175',
#  '617188',
#  '617199',
#  '617205',
#  '617210',
#  '617216',
#  '617217',
#  '617227',
#  '617230',
#  '617254',
#  '617262',
#  '617267',
#  '617281',
#  '617324',
#  '617370',
#  '617387',
#  '617410',
#  '617421',
#  '617424',
#  '617429',
#  '617442',
#  '617444',
#  '617446',
#  '617488',
#  '617494',
#  '617504',
#  '617516',
#  '617536']

# %%
id1_616146 = '616146'

# %%
dico_616146 = parse_fichier(chemin_test_xml_solo)
dico_616146
# Out:
# {'DocumentBudgetaire': {'@xmlns': 'http://www.minefi.gouv.fr/cp/demat/docbudgetaire',
#   'VersionSchema': {'@V': '88'},
#   'BlocEditeur': {'CodeEditeur': {'@V': 'GFI Progiciels, ASTRE GF V7.01 extraction 20141209 procedures 20190617, ASTRE Subventions V7.01'}},
#   'VersionOutil': [{'@outil': 'DSC_COMMON', '@version': '27'},
#    {'@outil': 'REMAT', '@version': '5_2019'}],
#   'Scellement': {'@md5': 'DA5B9388B8CD48E0C112A658DE6F61EC',
#    '@sha1': '9DFF3C342C43FDAAADE241774A055FA7D38526FB',
#    '@date': '2020-08-06T11:26:34'},
#   'EnTeteDocBudgetaire': {'DteStr': {'@V': '2020-03-17'},
#    'LibellePoste': {'@V': 'TRESORERIE LYON MUNICIPALE MET'},
#    'IdPost': {'@V': '069019'},
#    'LibelleColl': {'@V': 'VILLE DE LYON'},
#    'IdColl': {'@V': '21690123100011'},
#    'NatCEPL': {'@V': 'VILLE'}},
#   'Budget': {'EnTeteBudget': {'LibelleEtab': {'@V': 'BUDGET PRINCIPAL'},
#     'IdEtab': {'@V': '21690123100011'},
#     'CodColl': {'@V': '010'},
#     'CodBud': {'@V': '00'},
#     'Nomenclature': {'@V': 'M14-M14_COM_SUP3500'}},
#    'BlocBudget': {'NatDec': {'@V': '09'},
#     'Exer': {'@V': '2019'},
#     'ProjetBudget': {'@V': 'false'},
#     'DteDec': {'@V': '2020-05-25'},
#     'NatVote': {'@V': 'FcIc'},
#     'OpeEquip': {'@V': 'false'},
#     'VoteFormelChap': {'@V': 'false'},
#     'TypProv': {'@V': '2'},
#     'RefProv': {'@V': 'délibération N° 2005/6017 du 12/12/2005'},
#     'BudgPrec': {'@V': '1'},
#     'ReprRes': {'@V': '1'},
#     'NatFonc': {'@V': '3'},
#     'PresentationSimplifiee': {'@V': 'false'},
#     'DepFoncN2': {'@V': '0.00'},
#     'RecFoncN2': {'@V': '0.00'},
#     'DepInvN2': {'@V': '0.00'},
#     'RecInvN2': {'@V': '0.00'},
#     'CodTypBud': {'@V': 'P'}},
#    'InformationsGenerales': {'Information': [{'@Code': 'DtDelibAmort1An',
#       '@V': '17/12/2018'},
#      {'@Code': 'MtAmort1An', '@V': '500'},
#      {'@Code': 'PopTot', '@V': '523164'},
#      {'@Code': 'NbResSec', '@V': '11276'},
#      {'@Code': 'PotFisc', '@V': '712781702'},
#      {'@Code': 'PotFin', '@V': '777418595'},
#      {'@Code': 'MoyNatFin', '@V': '1568,13'},
#      {'@Code': 'MoyNatDepRFonc', '@V': '1163'},
#      {'@Code': 'ValDepRFonc', '@V': '1101'},
#      {'@Code': 'MoyNatProdImpo', '@V': '640'},
#      {'@Code': 'ValProdImpo', '@V': '705'},
#      {'@Code': 'MoyNatRecRFonc', '@V': '1326'},
#      {'@Code': 'ValRecRFonc', '@V': '1331'},
#      {'@Code': 'MoyNatDepEq', '@V': '215'},
#      {'@Code': 'ValDepEq', '@V': '224'},
#      {'@Code': 'MoyNatEncDettePop', '@V': '1144'},
#      {'@Code': 'ValEncDettePop', '@V': '745'},
#      {'@Code': 'MoyNatDGFPop', '@V': '206'},
#      {'@Code': 'ValDGFPop', '@V': '134'},
#      {'@Code': 'ValHab', '@V': '1454,64'},
#      {'@Code': 'MoyNatDepPers', '@V': '58,6%'},
#      {'@Code': 'ValDepPers', '@V': '57.2%'},
#      {'@Code': 'MoyNatDepFoncRemDette', '@V': '95,9%'},
#      {'@Code': 'ValDepFoncRemDette', '@V': '93.6%'},
#      {'@Code': 'MoyNatDepEqB', '@V': '16.2%'},
#      {'@Code': 'ValDepEqB', '@V': '16,9%'},
#      {'@Code': 'MoyNatEncDetteRecFonc', '@V': '86,3%'},
#      {'@Code': 'ValEncDetteRecFonc', '@V': '56%'},
#      {'@Code': 'SourceRatio',
#       '@V': 'Les collectivités locales en chiffres 2019 ; DGFiP ; calcul DGCL'},
#      {'@Code': 'EPCI', '@V': 'METROPOLE DE LYON'},
#      {'@Code': 'LieuCommDoc', '@V': 'Hôtel de Ville'}]},
#    'LigneBudget': [{'Nature': {'@V': '6336'},
#      'Fonction': {'@V': '322'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '82638.00'},
#      'MtReal': {'@V': '74680.90'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}},
#     {'Nature': {'@V': '6336'},
#      'Fonction': {'@V': '323'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '12063.00'},
#      'MtReal': {'@V': '8669.70'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}},
#     {'Nature': {'@V': '2313'},
#      'Fonction': {'@V': '213'},
#      'ContNat': {'@V': '23'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '836760.00'},
#      'MtReal': {'@V': '1815.05'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '836760.00'}},
#     {'Nature': {'@V': '6336'},
#      'Fonction': {'@V': '324'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '27450.00'},
#      'MtReal': {'@V': '25985.93'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '27450.00'}},
#     {'Nature': {'@V': '6336'},
#      'Fonction': {'@V': '33'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '418.00'},
#      'MtReal': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '418.00'}},
#     {'Nature': {'@V': '6336'},
#      'Fonction': {'@V': '40'},
#      'ContNat': {'@V': '012'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '20884.00'},
#      'MtReal': {'@V': '19446.99'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '20884.00'}},
#     {'Nature': {'@V': '2313'},
#      'Fonction': {'@V': '025'},
#      'ContNat': {'@V': '23'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '100080.00'},
#      'MtReal': {'@V': '0.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '100080.00'}},
#     {'Nature': {'@V': '2041622'},
#      'Fonction': {'@V': '523'},
#      'ContNat': {'@V': '204'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtRARPrec': {'@V': '115000.00'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '115000.00'},
#      'MtReal': {'@V': '115000.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '-115000.00'}},
#     {'Nature': {'@V': '7318'},
#      'Fonction': {'@V': '01'},
#      'ContNat': {'@V': '73'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '1000000.00'},
#      'MtReal': {'@V': '3004601.00'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '1000000.00'}},
#     {'Nature': {'@V': '73111'},
#      'Fonction': {'@V': '01'},
#      'ContNat': {'@V': '73'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'R'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V':
},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '859.00'}},
#     {'Nature': {'@V': '2183'},
#      'Fonction': {'@V': '026'},
#      'ContNat': {'@V': '21'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtRARPrec': {'@V': '2153.47'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '2153.47'},
#      'MtReal': {'@V': '2153.22'},
#      'OpBudg': {'@V': '0'},
#      'MtSup': {'@Code': 'BudgetHorsRAR', '@V': '-2153.47'}},
#     {'Nature': {'@V': '2033'},
#      'Fonction': {'@V': '422'},
#      'ContNat': {'@V': '20'},
#      'ArtSpe': {'@V': 'false'},
#      'CodRD': {'@V': 'D'},
#      'MtPrev': {'@V': '0.00'},
#      'CredOuv': {'@V': '3996.00'},
#      'MtReal': {'@V': '3996.00'},
#      'OpBudg': {'@V': '0'},
# ...
#        'MtCPAnt': {'@V': '331186.19'},
#        'MtCPOuv': {'@V': '174424.74'},
#        'MtCPReal': {'@V': '32044.46'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '372418.91'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/10'},
#        'LibAutori': {'@V': 'Réfection couvertures et étanchéïté 2015-2020'},
#        'MtAutoriPrec': {'@V': '2741000.0'},
#        'MtAutoriVote': {'@V': '20000.0'},
#        'MtCPAnt': {'@V': '2142239.54'},
#        'MtCPOuv': {'@V': '528749.65'},
#        'MtCPReal': {'@V': '294444.04'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '324316.42'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/11'},
#        'LibAutori': {'@V': 'Façades,mise en conformité & sécurité 2015-2020'},
#        'MtAutoriPrec': {'@V': '1211000.0'},
#        'MtAutoriVote': {'@V': '0.0'},
#        'MtCPAnt': {'@V': '890669.51'},
#        'MtCPOuv': {'@V': '120300.0'},
#        'MtCPReal': {'@V': '2905.2'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '317425.29'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/12'},
#        'LibAutori': {'@V': 'Rempl.des systèmes sécurité incendie 2015-2020'},
#        'MtAutoriPrec': {'@V': '3001701.82'},
#        'MtAutoriVote': {'@V': '-12421.6'},
#        'MtCPAnt': {'@V': '734063.72'},
#        'MtCPOuv': {'@V': '279967.04'},
#        'MtCPReal': {'@V': '105191.12'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '2150025.38'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/13'},
#        'LibAutori': {'@V': 'Mise en conform.inst.électriques des bât.2015-2020'},
#        'MtAutoriPrec': {'@V': '943300.0'},
#        'MtAutoriVote': {'@V': '0.0'},
#        'MtCPAnt': {'@V': '478210.93'},
#        'MtCPOuv': {'@V': '388891.82'},
#        'MtCPReal': {'@V': '292304.31'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '172784.76'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/14'},
#        'LibAutori': {'@V': 'Stabilité consolidation des ouvrages 2015-2020'},
#        'MtAutoriPrec': {'@V': '1660000.0'},
#        'MtAutoriVote': {'@V': '0.0'},
#        'MtCPAnt': {'@V': '1040789.77'},
#        'MtCPOuv': {'@V': '633744.89'},
#        'MtCPReal': {'@V': '398239.43'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '220970.8'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/15'},
#        'LibAutori': {'@V': 'Rénovation des ascenseurs 2015-2020'},
#        'MtAutoriPrec': {'@V': '1730000.0'},
#        'MtAutoriVote': {'@V': '0.0'},
#        'MtCPAnt': {'@V': '7251.52'},
#        'MtCPOuv': {'@V': '190000.0'},
#        'MtCPReal': {'@V': '25997.26'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '1696751.22'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 2015/17'},
#        'LibAutori': {'@V': 'Charges de copropriété 2015-2020'},
#        'MtAutoriPrec': {'@V': '961000.0'},
#        'MtAutoriVote': {'@V': '0.0'},
#        'MtCPAnt': {'@V': '703499.38'},
#        'MtCPOuv': {'@V': '0.0'},
#        'MtCPReal': {'@V': '0.0'},
#        'MtCredAFinanc_Sup_NPlus1': {'@V': '257500.62'}},
#       {'CodTypAutori': {'@V': 'P'},
#        'CodSTypAutori': {'@V': 'S'},
#        'NumAutori': {'@V': 'D 20020 
},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'false'}},
#       {'CodNatEtab': {'@V': '01'},
#        'LibCatEtab': {'@V': 'Caisse des Ecoles'},
#        'LibEtab': {'@V': 'CAISSE DES ECOLES DE LYON'},
#        'SiretEtab': {'@V': '26691102300106'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'false'}},
#       {'CodNatEtab': {'@V': '01'},
#        'LibCatEtab': {'@V': 'Régie personnalisée'},
#        'LibEtab': {'@V': 'HALLE TONY GARNIER'},
#        'SiretEtab': {'@V': '42818798300013'},
#        'DtCreatEtab': {'@V': '1999-10-01'},
#        'NumDelibEtab': {'@V': '1999/4202'},
#        'DtDelibEtab': {'@V': '1999-09-20'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC INDUSTRIEL ET COMMERCIAL'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '01'},
#        'LibCatEtab': {'@V': 'EPCC'},
#        'LibEtab': {'@V': 'ECOLE NATIONALE SUPERIEURE DES BEAUX ARTS DE LYON'},
#        'SiretEtab': {'@V': '20002676300017'},
#        'DtCreatEtab': {'@V': '2011-01-01'},
#        'NumDelibEtab': {'@V': '2010/2249'},
#        'DtDelibEtab': {'@V': '2010-03-01'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'false'}},
#       {'CodNatEtab': {'@V': '02'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'THEATRE DES CELESTINS'},
#        'SiretEtab': {'@V': '21690123103627'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '02'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'HALLES DE LYON PART-DIEU'},
#        'SiretEtab': {'@V': '21690123103734'},
#        'DtCreatEtab': {'@V': '2012-01-01'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC INDUSTRIEL ET COMMERCIAL'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '02'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'AUDITORIUM - ORCHESTRE NATIONAL DE LYON '},
#        'SiretEtab': {'@V': '21690123102892'},
#        'DtCreatEtab': {'@V': '2015-01-01'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Activité Culture '},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'false'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Evénements et animation'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Location de la salle des fêtes de la Ficelle'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Location de la salle des fêtes de la Garenne'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Location de locaux '},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Location des kiosques'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Location du Palais des Sports'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}},
#       {'CodNatEtab': {'@V': '03'},
#        'LibCatEtab': {'@V': 'Régie simple'},
#        'LibEtab': {'@V': 'Nettoyage des graffitis'},
#        'SiretEtab': {'@V': '21690123100011'},
#        'LibNatActivEtab': {'@V': 'SERVICE PUBLIC ADMINISTRATIF'},
#        'IndicTVAEtab': {'@V': 'true'}}]},
#     'DATA_SOMMAIRE': {'SOMMAIRE': [{'CodeAnnexe': {'@V': 'PG'},
#        'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'SOM'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'I-A'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'I-B'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-A3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-B1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'II-B2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-A1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-A2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'III-B3'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A1.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.4'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.5'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.7'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.8'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A2.9'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A4'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A5'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A6.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A6.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.1.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.1.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.2.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.2.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.3.1'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A7.3.2'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A8'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A9'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A10.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A10.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A10.3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-A10.4'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A10.5'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A11'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-A12'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.3'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.4'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.5'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-B1.7'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B2.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B2.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-B3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C1.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C1.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.2'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.3'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.4'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.5'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'IV-C3.6'}, 'Present': {'@V': 'false'}},
#       {'CodeAnnexe': {'@V': 'IV-D1'}, 'Present': {'@V': 'true'}},
#       {'CodeAnnexe': {'@V': 'ARS'}, 'Present': {'@V': 'true'}}]}}}}}

# %%
metadonnees_616146 = dico_616146['DocumentBudgetaire']['EnTeteDocBudgetaire']
metadonnees_616146['Id_Fichier'] = {'@V' : id1_616146}
metadonnees_616146
# Out:
# {'DteStr': {'@V': '2020-03-17'},
#  'LibellePoste': {'@V': 'TRESORERIE LYON MUNICIPALE MET'},
#  'IdPost': {'@V': '069019'},
#  'LibelleColl': {'@V': 'VILLE DE LYON'},
#  'IdColl': {'@V': '21690123100011'},
#  'NatCEPL': {'@V': 'VILLE'},
#  'Id_Fichier': {'@V': '616146'}}

# %% [markdown]
# Bah voilà le problème, c'est sale.

# %%
docbase_616146 = dico_616146['DocumentBudgetaire']['Budget']['LigneBudget']
for i in docbase_616146 : 
 i.update(metadonnees_616146)
df_616146 = pd.DataFrame(docbase_616146)
df_616146.head(3)
# Out:
#            Nature       Fonction        ContNat           ArtSpe        CodRD  \
# 0  {'@V': '6336'}  {'@V': '322'}  {'@V': '012'}  {'@V': 'false'}  {'@V': 'D'}
# 1  {'@V': '6336'}  {'@V': '323'}  {'@V': '012'}  {'@V': 'false'}  {'@V': 'D'}
# 2  {'@V': '2313'}  {'@V': '213'}   {'@V': '23'}  {'@V': 'false'}  {'@V': 'R'}
#
#            MtPrev              CredOuv              MtReal       OpBudg  \
# 0  {'@V': '0.00'}   {'@V': '82638.00'}  {'@V': '74680.90'}  {'@V': '0'}
# 1  {'@V': '0.00'}   {'@V': '12063.00'}   {'@V': '8669.70'}  {'@V': '0'}
# 2  {'@V': '0.00'}  {'@V': '836760.00'}   {'@V': '1815.05'}  {'@V': '0'}
#
#                                            MtSup  ...  \
# 0   {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...
# 1   {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...
# 2  {'@Code': 'BudgetHorsRAR', '@V': '836760.00'}  ...
#
#                LibelleColl                    IdColl          NatCEPL  \
# 0  {'@V': 'VILLE DE LYON'}  {'@V': '21690123100011'}  {'@V': 'VILLE'}
# 1  {'@V': 'VILLE DE LYON'}  {'@V': '21690123100011'}  {'@V': 'VILLE'}
# 2  {'@V': 'VILLE DE LYON'}  {'@V': '21690123100011'}  {'@V': 'VILLE'}
#
#          Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte ContOp OpeCpteTiers
# 0  {'@V': '616146'}       NaN       NaN       NaN     NaN    NaN          NaN
# 1  {'@V': '616146'}       NaN       NaN       NaN     NaN    NaN          NaN
# 2  {'@V': '616146'}       NaN       NaN       NaN     NaN    NaN          NaN
#
# [3 rows x 23 columns]

# %% [markdown]
# Il ne faut pas que le nettoyage affecte les colonnes MtSup et CaracSup pour une raison simple : ce ne sera plus des dico, ça ressemblera à rien

# %%
def nettoyage_individuel(dataframe : pd.DataFrame) -> pd.DataFrame :
 nettoyage = lambda x : str(x).replace("{'@V': '", "").replace("'}", "")
 for col in dataframe.columns : 
  if col in ['MtSup', 'CaracSup'] : 
   continue 
  else :
   dataframe[col] = dataframe[col].apply(nettoyage)
 return dataframe

# %%
df_616146_clean = nettoyage_individuel(df_616146)
df_616146_clean.head(5)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev    CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00   82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00   12063.00   8669.70      0
# 2   2313      213      23  false     R   0.00  836760.00   1815.05      0
# 3   6336      324     012  false     D   0.00   27450.00  25985.93      0
# 4   6336       33     012  false     D   0.00     418.00      0.00      0
#
#                                            MtSup  ...    LibelleColl  \
# 0   {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...  VILLE DE LYON
# 1   {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...  VILLE DE LYON
# 2  {'@Code': 'BudgetHorsRAR', '@V': '836760.00'}  ...  VILLE DE LYON
# 3   {'@Code': 'BudgetHorsRAR', '@V': '27450.00'}  ...  VILLE DE LYON
# 4     {'@Code': 'BudgetHorsRAR', '@V': '418.00'}  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
# 2  21690123100011   VILLE     616146       nan       nan       nan     nan
# 3  21690123100011   VILLE     616146       nan       nan       nan     nan
# 4  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
# 2    nan          nan
# 3    nan          nan
# 4    nan          nan
#
# [5 rows x 23 columns]

# %% [markdown]
# C'est le dataframe qu'on veut, maintenant on envoie ça en parquet.
#
# On va aussi tenter avec un autre engine, pour avoir l'erreur sous une autre forme

# %%
df_616146_clean.to_parquet(f'./fichiers/todo_parquet/{id1_616146}', engine='pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# d:\projets_data\budget_communes\etl_hub_coll\renouveau_05_12.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/projets_data/budget_communes/etl_hub_coll/renouveau_05_12.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> df_616146_clean.to_parquet(f'./fichiers/todo_parquet/{id1_616146}', engine='pyarrow')
#
# File d:\python\Lib\site-packages\pandas\core\frame.py:2970, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2882 """
#    2883 Write a DataFrame to the binary parquet format.
#    2884
#    (...)
#    2966 >>> content = f.read()
#    2967 """
#    2968 from pandas.io.parquet import to_parquet
# -> 2970 return to_parquet(
#    2971     self,
#    2972     path,
#    2973     engine,
#    2974     compression=compression,
#    2975     index=index,
#    2976     partition_cols=partition_cols,
#    2977     storage_options=storage_options,
#    2978     **kwargs,
#    2979 )
#
# File d:\python\Lib\site-packages\pandas\io\parquet.py:483, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     479 impl = get_engine(engine)
#     481 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 483 impl.write(
#     484     df,
#     485     path_or_buf,
#     486     compression=compression,
#     487     index=index,
#     488     partition_cols=partition_cols,
#     489     storage_options=storage_options,
#     490     filesystem=filesystem,
#     491     **kwargs,
#     492 )
#     494 if path is None:
#     495     assert isinstance(path_or_buf, io.BytesIO)
#
# File d:\python\Lib\site-packages\pandas\io\parquet.py:189, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     186 if index is not None:
#     187     from_pandas_kwargs["preserve_index"] = index
# --> 189 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     191 if df.attrs:
#     192     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File d:\python\Lib\site-packages\pyarrow\table.pxi:3869, in pyarrow.lib.Table.from_pandas()
#
# File d:\python\Lib\site-packages\pyarrow\pandas_compat.py:613, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     608     return (isinstance(arr, np.ndarray) and
#     609             arr.flags.contiguous and
#     610             issubclass(arr.dtype.type, np.integer))
#     612 if nthreads == 1:
# --> 613     arrays = [convert_column(c, f)
#     614               for c, f in zip(columns_to_convert, convert_fields)]
#     615 else:
#     616     arrays = []
#
# File d:\python\Lib\site-packages\pyarrow\pandas_compat.py:613, in <listcomp>(.0)
#     608     return (isinstance(arr, np.ndarray) and
#     609             arr.flags.contiguous and
#     610             issubclass(arr.dtype.type, np.integer))
#     612 if nthreads == 1:
# --> 613     arrays = [convert_column(c, f)
#     614               for c, f in zip(columns_to_convert, convert_fields)]
#     615 else:
#     616     arrays = []
#
# File d:\python\Lib\site-packages\pyarrow\pandas_compat.py:600, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     595 except (pa.ArrowInvalid,
#     596         pa.ArrowNotImplementedError,
#     597         pa.ArrowTypeError) as e:
#     598     e.args += ("Conversion failed for column {!s} with type {!s}"
#     599                .format(col.name, col.dtype),)
# --> 600     raise e
#     601 if not field_nullable and result.null_count > 0:
#     602     raise ValueError("Field {} was non-nullable but pandas column "
#     603                      "had {} null values".format(str(field),
#     604                                                  result.null_count))
#
# File d:\python\Lib\site-packages\pyarrow\pandas_compat.py:594, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     591     type_ = field.type
#     593 try:
# --> 594     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     595 except (pa.ArrowInvalid,
#     596         pa.ArrowNotImplementedError,
#     597         pa.ArrowTypeError) as e:
#     598     e.args += ("Conversion failed for column {!s} with type {!s}"
#     599                .format(col.name, col.dtype),)
#
# File d:\python\Lib\site-packages\pyarrow\array.pxi:340, in pyarrow.lib.array()
#
# File d:\python\Lib\site-packages\pyarrow\array.pxi:86, in pyarrow.lib._ndarray_to_array()
#
# File d:\python\Lib\site-packages\pyarrow\error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowInvalid: ('cannot mix list and non-list, non-null values', 'Conversion failed for column MtSup with type object')

# %% [markdown]
# Dooooooooooooonc.

# %%
df_616146_clean.to_parquet(f'./fichiers/todo_parquet/{id1_616146}', engine='fastparquet')

# %% [markdown]
# On va quand même tenter de nettoyer pour tester sur pyarrow

# %%
df_parquet_616146 = pd.read_parquet('./fichiers/todo_parquet/616146')
df_parquet_616146.head(5)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev    CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00   82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00   12063.00   8669.70      0
# 2   2313      213      23  false     R   0.00  836760.00   1815.05      0
# 3   6336      324     012  false     D   0.00   27450.00  25985.93      0
# 4   6336       33     012  false     D   0.00     418.00      0.00      0
#
#                                            MtSup  ...    LibelleColl  \
# 0   b'{"@Code":"BudgetHorsRAR","@V":"82638.00"}'  ...  VILLE DE LYON
# 1   b'{"@Code":"BudgetHorsRAR","@V":"12063.00"}'  ...  VILLE DE LYON
# 2  b'{"@Code":"BudgetHorsRAR","@V":"836760.00"}'  ...  VILLE DE LYON
# 3   b'{"@Code":"BudgetHorsRAR","@V":"27450.00"}'  ...  VILLE DE LYON
# 4     b'{"@Code":"BudgetHorsRAR","@V":"418.00"}'  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
# 2  21690123100011   VILLE     616146       nan       nan       nan     nan
# 3  21690123100011   VILLE     616146       nan       nan       nan     nan
# 4  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
# 2    nan          nan
# 3    nan          nan
# 4    nan          nan
#
# [5 rows x 23 columns]

# %%
df_616146_clean.head(2)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev   CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00  82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00  12063.00   8669.70      0
#
#                                           MtSup  ...    LibelleColl  \
# 0  {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...  VILLE DE LYON
# 1  {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
#
# [2 rows x 23 columns]

# %%
df_616146_pyarrow = df_616146_clean.copy()
df_616146_pyarrow['MtSup'] = df_616146_pyarrow['MtSup'].astype(str)
df_616146_pyarrow.head(2)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev   CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00  82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00  12063.00   8669.70      0
#
#                                           MtSup  ...    LibelleColl  \
# 0  {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...  VILLE DE LYON
# 1  {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
#
# [2 rows x 23 columns]

# %%
df_616146_pyarrow['CaracSup'] = df_616146_pyarrow['CaracSup'].astype(str)
df_616146_pyarrow.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\python\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CaracSup'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\projets_data\budget_communes\etl_hub_coll\renouveau_05_12.ipynb Cell 30 line 2
#       <a href='vscode-notebook-cell:/d%3A/projets_data/budget_communes/etl_hub_coll/renouveau_05_12.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> df_616146_pyarrow = df_616146_pyarrow.reset_index(drop=True)
# ----> <a href='vscode-notebook-cell:/d%3A/projets_data/budget_communes/etl_hub_coll/renouveau_05_12.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> df_616146_pyarrow['CaracSup'] = df_616146_pyarrow['CaracSup'].astype(str)
#       <a href='vscode-notebook-cell:/d%3A/projets_data/budget_communes/etl_hub_coll/renouveau_05_12.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a> df_616146_pyarrow.head(2)
#
# File d:\python\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File d:\python\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'CaracSup'

# %%
df_616146_pyarrow.columns
# Out:
# Index(['Nature', 'Fonction', 'ContNat', 'ArtSpe', 'CodRD', 'MtPrev', 'CredOuv',
#        'MtReal', 'OpBudg', 'MtSup', 'DteStr', 'LibellePoste', 'IdPost',
#        'LibelleColl', 'IdColl', 'NatCEPL', 'Id_Fichier', 'MtRARPrec',
#        'TypOpBudg', 'MtRAR3112', 'LibCpte', 'ContOp', 'OpeCpteTiers'],
#       dtype='object')

# %% [markdown]
# Il n'y a pas de caracsup, c'est le défaut de faire des test sur des fichiers seuls. On va juste vérifier que le fichier n'ait pas disparu pendant le chemin

# %%
df_616146.columns
# Out:
# Index(['Nature', 'Fonction', 'ContNat', 'ArtSpe', 'CodRD', 'MtPrev', 'CredOuv',
#        'MtReal', 'OpBudg', 'MtSup', 'DteStr', 'LibellePoste', 'IdPost',
#        'LibelleColl', 'IdColl', 'NatCEPL', 'Id_Fichier', 'MtRARPrec',
#        'TypOpBudg', 'MtRAR3112', 'LibCpte', 'ContOp', 'OpeCpteTiers'],
#       dtype='object')

# %%
df_616146_pyarrow = df_616146_pyarrow.reset_index(drop=True)
df_616146_pyarrow.head(3)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev    CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00   82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00   12063.00   8669.70      0
# 2   2313      213      23  false     R   0.00  836760.00   1815.05      0
#
#                                            MtSup  ...    LibelleColl  \
# 0   {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...  VILLE DE LYON
# 1   {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...  VILLE DE LYON
# 2  {'@Code': 'BudgetHorsRAR', '@V': '836760.00'}  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
# 2  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
# 2    nan          nan
#
# [3 rows x 23 columns]

# %%
df_616146_pyarrow.to_parquet(f'./fichiers/todo_parquet/{id1_616146}_pyarrow', engine='pyarrow')

# %%
df_parquet_arrow = pd.read_parquet(f'./fichiers/todo_parquet/616146_pyarrow')
df_parquet_arrow.head(2)
# Out:
#   Nature Fonction ContNat ArtSpe CodRD MtPrev   CredOuv    MtReal OpBudg  \
# 0   6336      322     012  false     D   0.00  82638.00  74680.90      0
# 1   6336      323     012  false     D   0.00  12063.00   8669.70      0
#
#                                           MtSup  ...    LibelleColl  \
# 0  {'@Code': 'BudgetHorsRAR', '@V': '82638.00'}  ...  VILLE DE LYON
# 1  {'@Code': 'BudgetHorsRAR', '@V': '12063.00'}  ...  VILLE DE LYON
#
#            IdColl NatCEPL Id_Fichier MtRARPrec TypOpBudg MtRAR3112 LibCpte  \
# 0  21690123100011   VILLE     616146       nan       nan       nan     nan
# 1  21690123100011   VILLE     616146       nan       nan       nan     nan
#
#   ContOp OpeCpteTiers
# 0    nan          nan
# 1    nan          nan
#
# [2 rows x 23 columns]

# %% [markdown]
# Pyarrow est bien plus rapide. On va donc rester dessus et créer une fonction de nettoyage qui s'adapte à l'existence de CaracSup

# %%
def nettoyage_adaptatif(dataframe : pd.DataFrame) -> pd.DataFrame :
 nettoyage = lambda x : str(x).replace("{'@V': '", "").replace("'}", "")
 for col in dataframe.columns : 
  if col in ['MtSup', 'CaracSup'] : 
   dataframe[col] = dataframe[col].astype(str) 
  else :
   dataframe[col] = dataframe[col].apply(nettoyage)
 dataframe_propre = dataframe.reset_index(drop=True)
 return dataframe_propre

# %% [markdown]
# On va refaire un test avec ce nouveau nettoyage sur les 500 fichiers

# %%
def Extraction_xml_to_parquet_v2(chemin) : 
 ''' Traite les XML et les envoies sous format parquet, nettoyage necessaire pour être sous forme de parquet'''
 for fichier in glob.glob(os.path.join(chemin, "*.gz")) : 
  try : 
   id_fichier = _isolement_id(fichier)
   dico = parse_fichier(fichier)
   metadonnees = dico['DocumentBudgetaire']['EnTeteDocBudgetaire']
   metadonnees['Id_Fichier'] = {'@V' : id_fichier}
   docbase = dico['DocumentBudgetaire']['Budget']['LigneBudget']
   for i in docbase : 
      i.update(metadonnees)
   df_base = pd.DataFrame(docbase)
   df_propre = nettoyage_adaptatif(df_base)
   df_propre.to_parquet(f'./fichiers/todo_parquet/{id_fichier}_pyarrow', engine='pyarrow')
   #shutil.move(fichier, './fichiers/done_xml/')
  except Exception as e : 
    print(f'Erreur fichier {fichier}, extraction impossible')
    #shutil.move(fichier, './fichiers/todo_xml/error/')
    print(e)
    continue

# %%
Extraction_xml_to_parquet_v2(DOSSIER_500)

# %% [markdown]
# Victoire, sûrement de courte durée. En tout cas on a la task 1 pour airflow, peut être.

# %%
df_numero_osef = pd.read_parquet('./fichiers/todo_parquet/612027_pyarrow')
df_numero_osef.head(2)
# Out:
#   Nature ContNat ArtSpe CodRD MtBudgPrec MtPropNouv  MtPrev CredOuv OpBudg  \
# 0   6232     011  false     D     200.00     850.00  850.00  850.00      0
# 1   6288     011  false     D    2597.00     360.61  360.61  360.61      0
#
#                                          MtSup  \
# 0   {'@V': '200.00', '@Code': 'BudgetHorsRAR'}
# 1  {'@V': '2597.00', '@Code': 'BudgetHorsRAR'}
#
#                           CaracSup      DteStr            LibellePoste  \
# 0  {'@V': 'F', '@Code': 'Section'}  2020-08-01  Trésorerie de BEAUFORT
# 1  {'@V': 'F', '@Code': 'Section'}  2020-08-01  Trésorerie de BEAUFORT
#
#    IdPost       LibelleColl          IdColl  NatCEPL Departement Id_Fichier
# 0  039005  Commune de AUGEA  26390025000014  COMMUNE          39     612027
# 1  039005  Commune de AUGEA  26390025000014  COMMUNE          39     612027
