# %%
import time 
import logging
import os
import sqlite3
import pathlib
import glob
import gzip 

import pandas as pd
import xmltodict

DOSSIER_PARENT = "."
DOSSIER_SOURCE = "./todo/"
DOSSIER_SORTIE = "./done/"
BDD = 'bdd_actes_budgetaires_gz.db'
NOM_CSV = 'donnees_budgetaires.csv'

# %%
logging.basicConfig(level=logging.INFO,
                    filename='traitement.log', 
                    filemode='w')

def timing_decorator(func):
 def wrapper(*args, **kwargs):
  start_time = time.time()
  result = func(*args, **kwargs)
  end_time = time.time()
  execution_time = end_time - start_time
  print(f"{func.__name__} a pris {execution_time:.4f} secondes pour s'exécuter.")
  return result
 return wrapper

def parsing_fichier(chemin) : 
 with gzip.open(chemin, 'rb') as fichier_ouvert : 
  fichier_xml_gzip = fichier_ouvert.read()
  fichier_xml = fichier_xml_gzip.decode('latin-1')
  fichier_dict = xmltodict.parse(fichier_xml)
 return fichier_dict

def _extract_ligne_budget(data_dict: dict) -> pd.DataFrame : 
 "Sépare les sous clefs lignes budget, sans nettoyage"
 ligne_budget = data_dict['DocumentBudgetaire']['Budget']['LigneBudget']
 df_ligne_budget = pd.DataFrame(ligne_budget)
 return df_ligne_budget

def _extract_metadonnees(data_dict : dict) -> pd.DataFrame : 
 "Sépare les sous clefs de métadonnées, sans nettoyage"
 metadonnees = data_dict['DocumentBudgetaire']['EnTeteDocBudgetaire']
 df_metadonnees = pd.DataFrame(metadonnees)
 return df_metadonnees

def _extract_id(fichier) : 
 "Extrait l'id du nom du fichier"
 val_IdFichier = fichier.split("-")[-1].split('.')[0]
 IdFichier = {"IdFichier" : val_IdFichier}
 df_id = pd.DataFrame(IdFichier, index = [0])
 return df_id

def _extract_date(data_dict : dict) -> pd.DataFrame : 
 date = data_dict['DocumentBudgetaire']['Budget']['BlocBudget']
 df_date = pd.DataFrame(date)
 return df_date

def extraction_donnees(data_dict : dict, fichier) : 
 df_ligne_budget =_extract_ligne_budget(data_dict)
 df_metadonnees = _extract_metadonnees(data_dict)
 df_date = _extract_date(data_dict)
 df_id = _extract_id(fichier)
 return df_ligne_budget, df_metadonnees, df_date, df_id

def assemblage(df_principal: pd.DataFrame, 
                         df_meta: pd.DataFrame, 
                         df_id: pd.DataFrame,
                         df_date : pd.DataFrame) -> pd.DataFrame:
 """ Assemble les dataFrame contenant les metadonnees,
 la version schema et les lignes budgetaires """
 colonnes_a_conserver = ["IdFichier", "DteDec", "LibelleColl",
                         "IdColl","Nature","LibCpte",
                         "Fonction","Operation",
                         "ContNat","ArtSpe",
                         "ContFon", "ContOp",
                         "CodRD","MtBudgPrec",
                         "MtRARPrec","MtPropNouv",
                         "MtPrev","CredOuv",
                         "MtReal","MtRAR3112",
                         "OpBudg","TypOpBudg",
                         "OpeCpteTiers"
                        ]
 
 df_final = pd.DataFrame(columns=colonnes_a_conserver)
 df_schem = pd.concat([df_id] * len(df_principal), ignore_index=True)
 df_meta = pd.concat([df_meta] * len(df_principal), ignore_index=True)
 df_date = pd.concat([df_date] * len(df_principal), ignore_index=True)

 for col in df_id.columns:
  if col in colonnes_a_conserver:
    df_final[col] = df_schem[col]

 for col in df_meta.columns:
  if col in colonnes_a_conserver:
    df_final[col] = df_meta[col]

 for col in df_principal.columns:
  if col in colonnes_a_conserver:
    df_final[col] = df_principal[col]

 for col in df_date.columns:
  if col in colonnes_a_conserver:
    df_final[col] = df_date[col]

 df_final = df_final.dropna(axis=1, how='all')
 return df_final

def nettoyage_lambda(df : pd.DataFrame) -> pd.DataFrame : 
 "Nettoie les données pour se débarasser des @V"
 nettoyage = lambda x : str(x).replace("{'@V': '", "").replace("'}", "")
 for col in df.columns : 
  df[col] = df[col].apply(nettoyage)
 return df 

def insertion_bdd(df_final: pd.DataFrame):
 """ insert dans une bdd les données maintenant transformées et en sort un csv à jour """
 chemin_bdd = os.path.join(DOSSIER_PARENT, BDD)
 conn = sqlite3.connect(chemin_bdd)
 df_final.to_sql('acte_budgetaire_gz', conn,
                    if_exists='append', index=False)
 
def creation_csv() :
 conn = sqlite3.connect(BDD)
 cursor = conn.cursor()
 info = cursor.execute('''Select * from acte_budgetaire_gz''')
 df = pd.DataFrame(info)
 fichier_csv = os.path.join(DOSSIER_PARENT, NOM_CSV)
 df.to_csv(fichier_csv, index=False)
 conn.close()

def deplacement_fichier(fichier_a_deplacer, dossier_destination):
 """ Déplace le fichier du dossier source au dossier fini"""
 chemin_source = pathlib.Path(fichier_a_deplacer)
 chemin_destination = pathlib.Path(dossier_destination) / chemin_source.name
 chemin_source.rename(chemin_destination)

def clean_bdd_test() : 
 conn = sqlite3.connect(BDD)
 cursor = conn.cursor()
 cursor.execute('''DELETE FROM acte_budgetaire_gz ''')
 conn.commit()
 conn.close()

def supr_csv_test(dossier = DOSSIER_PARENT, nom_fichier = NOM_CSV) :
 fichier_a_supprimer = os.path.join(dossier, nom_fichier)
 os.remove(fichier_a_supprimer)

@timing_decorator
def main():
 """ Traitement global, extrait et transforme les fichiers XML dans DOSSIER_SOURCE
    pour les insérer dans une bdd et en faire un csv"""
 liste_des_fichier_source = glob.glob(os.path.join(DOSSIER_SOURCE, "*.gz"))
 liste_des_fichier_traite = glob.glob(os.path.join(DOSSIER_SORTIE, "*.gz"))
 liste_des_df = []
 for fichier in liste_des_fichier_source:
  logging.info(f'Debut du travail sur {fichier}')
    # Sécurité permettant de ne pas injecter des doublons
  if fichier in liste_des_fichier_traite : 
   logging.error(f'Le fichier {fichier} a déjà été traité')
   return None 
  else : 
   data_dict = parsing_fichier(fichier)
   if data_dict is not None:
    df_budget = _extract_ligne_budget(data_dict)
    df_metadonnees = _extract_metadonnees(data_dict)
    df_id = _extract_id(fichier)
    df_date = _extract_date(data_dict)
    df_final = assemblage(
                df_budget, df_metadonnees, df_id, df_date)
    liste_des_df.append(df_final)
    logging.info(f'Fin du travail sur {fichier}')
 df_session = pd.concat(liste_des_df, ignore_index = True)
 nettoyage_lambda(df_session)
 insertion_bdd(df_session)
 creation_csv()
 clean_bdd_test()

# %%
for _ in range(10):
    main()
# Out:
# main a pris 6.1959 secondes pour s'exécuter.
# main a pris 6.5505 secondes pour s'exécuter.
# main a pris 6.8662 secondes pour s'exécuter.
# main a pris 6.8334 secondes pour s'exécuter.
# main a pris 7.2359 secondes pour s'exécuter.
# main a pris 7.4756 secondes pour s'exécuter.
# main a pris 7.4985 secondes pour s'exécuter.
# main a pris 7.5651 secondes pour s'exécuter.
# main a pris 8.0656 secondes pour s'exécuter.
# main a pris 8.1442 secondes pour s'exécuter.

# %%
liste_des_fichier_source = glob.glob(os.path.join(DOSSIER_SOURCE, "*.gz"))
liste_des_fichier_traite = glob.glob(os.path.join(DOSSIER_SORTIE, "*.gz"))

def parse_id(fichier) : 
 val_IdFichier = fichier.split("-")[-1].split('.')[0]
 return val_IdFichier

def test_comprehension():
    conn = sqlite3.connect(BDD)
    cursor = conn.cursor()
    cursor.execute(''' SELECT DISTINCT IdFichier FROM acte_budgetaire_gz ''')
    ligne_sql_int = [int(x[0]) for x in cursor.fetchall()]
    return ligne_sql_int

files_to_print = [fichier for fichier in liste_des_fichier_source if int(parse_id(fichier)) not in test_comprehension()]


# Parcourez la liste des fichiers à imprimer
def main_safe()
for fichier in files_to_print:
    print(f"{fichier} vous bisou")

# %%
from lxml import etree 

def parse_fichier_xml(chemin) -> dict:
    """ Transforme le fichier xml en dictionnaire python """
    with open(chemin, "r", encoding="latin-1") as fichier_ouvert:
        fichier_xml = fichier_ouvert.read()
        data_dict = xmltodict.parse(fichier_xml)
    return data_dict

way_autrexml = "./autre_xml/ppal-bp-2021.xml"

arbre = etree.parse(way_autrexml)
racine = arbre.getroot()
enfants = racine.getchildren()
attributs = racine.attrib
text = racine.text
enfants
# Out:
# [<Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}VersionSchema at 0x22f8b889180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}BlocEditeur at 0x22f8247e880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}VersionOutil at 0x22f8b8f9c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}VersionOutil at 0x22f8b8d62c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Scellement at 0x22f8b8d4f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}EnTeteDocBudgetaire at 0x22f8b8d7dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Budget at 0x22f8b8d7c40>]

# %%
num_enfant = 6 
entete = enfants[num_enfant]
arbreentete = etree.ElementTree(entete)
larbreentete = arbreentete.getroot()
attribentete = arbreentete.getroot().attrib
textarbre = arbreentete.getroot().text
larbreentete.getchildren()
# Out:
# [<Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}EnTeteBudget at 0x22f8b8d3600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}BlocBudget at 0x22f8c953000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}InformationsGenerales at 0x22f8b8b1cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f824f4480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9942c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c994900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c994240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c994480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c994bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c997600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c997140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9952c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c994a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9951c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995d00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9958c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9955c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9957c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9959c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c997500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9960c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9961c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c995280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c990140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9904c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9903c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c990300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9914c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c990780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c990740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9921c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9934c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9922c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9926c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9927c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9912c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9925c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9920c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9939c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9929c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9935c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991d00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993b40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9930c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9937c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993d00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993f80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c991280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c992440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c993940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b79c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b72c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b42c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b40c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b45c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b46c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b50c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b44c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4f80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b52c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b54c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b55c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b51c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b47c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b56c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b57c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5b40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b59c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b58c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5f80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b53c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b65c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b63c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b48c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b61c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b69c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b62c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b4cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b71c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b68c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7b40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b5a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7f80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b6740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b75c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b67c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b78c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b77c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b7280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcb00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc5c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd4c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd0c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcf00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc0c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc4c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc9c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bca40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bca80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcb40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bc8c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bca00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcb80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcbc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcf80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcc40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcc80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcc00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bce40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bce80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcfc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcd80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bce00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bccc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcd00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcd40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcdc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bcf40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd6c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd9c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bda00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bda40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bda80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdb00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdb40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdb80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdbc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdc00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdc40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdc80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdcc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdd00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdd40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdd80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bddc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bde00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bde40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bde80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdf00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdf40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdf80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bdfc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be0c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be1c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be2c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be3c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd5c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9971c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c996000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f824ecb80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be5c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be6c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bea00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be7c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be9c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bea40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bea80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9beac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9beb00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9beb40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9beb80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bebc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bec00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bec40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bec80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9becc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bed00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bed40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bed80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bedc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bee00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bee40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bee80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9beec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bef00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bef40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bef80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9befc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf0c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf1c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf2c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf3c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf4c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf5c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf6c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf7c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfa80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf9c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfa00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfb80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfb00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfd00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfc00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bffc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfcc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfdc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfe00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfd40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfe80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bff00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bff80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bf8c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfc80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfbc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bfec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9be940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bff40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd8c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bd840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b97c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b8fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b84c0>,
# ...
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ba1c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bbd00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bbe00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bbe80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b82c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb7c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ba6c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b9280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ba8c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb3c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9baa40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bba80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b8540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bbf00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ba240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9b9540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9bb980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c80c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c81c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c82c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c83c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c84c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c85c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c86c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c87c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c88c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c89c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8b40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8d00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8ec0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c90c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c91c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c92c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c93c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c94c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c95c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c96c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9780>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c97c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9800>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9840>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9880>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c98c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9900>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9940>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9980>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c99c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9a00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9a40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9a80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9ac0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9b00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9b40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9b80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9bc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9c00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9c40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9c80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9d00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9d40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9d80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9dc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c8cc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9e00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9e80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9e40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9f00>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9f40>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9f80>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9c9fc0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca000>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca080>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca0c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca100>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca140>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca040>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca180>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca1c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca200>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca240>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca280>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca2c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca300>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca340>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca380>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca3c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca400>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca440>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca480>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca4c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca500>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca540>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca580>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca5c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca600>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca640>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca680>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca6c0>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca700>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget at 0x22f8c9ca740>,
#  <Element {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Annexes at 0x22f8c9ca780>]

# %%
lignes_budget_list = []

# Parcourez les enfants de larbreentete
for caca in larbreentete.getchildren():
    # Vérifiez si l'enfant est de type "lignes budget"
    if caca.tag == "{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget":
        # Créez un dictionnaire pour stocker les informations de cette ligne budget
        ligne_budget_dict = {}
        
        # Accédez aux informations à l'intérieur de l'enfant "lignes budget"
        for sous_element in caca.getchildren():
            # Utilisez le nom de la balise comme clé et le texte à l'intérieur comme valeur
            ligne_budget_dict[sous_element.tag] = sous_element.attrib
        
        # Ajoutez le dictionnaire de cette ligne budget à la liste
        lignes_budget_list.append(ligne_budget_dict)

# %%
lignes_budget_list
# Out:
# [{'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '90'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '5500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '8500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '8500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '5500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '251'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '750.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '750.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '324'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1210.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1210.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1210.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1210.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '311'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '822'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '524'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '30000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '25000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '25000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '30000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '41000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '41300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '41300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '41000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '54000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '53700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '53700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '54000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '34700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '24250.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '24250.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '34700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60611'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '150.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '150.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '90'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '103500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '115500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '115500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '103500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '251'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '13000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '13000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '13000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '13000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '324'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '3000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '80520.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '82520.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '82520.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '80520.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '311'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '32000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '34000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '34000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '32000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '822'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '25500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '25000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '25000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '25500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '524'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '70000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '70000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '70000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '70000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '320500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '286500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '286500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '320500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '63500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '63500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '63500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '63500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '01'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60612'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '82200.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '78700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '78700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '82200.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '700.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '900.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '900.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '900.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '900.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '112'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '20000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '20000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '20000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '20000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60622'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '021'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '2500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '2500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '2500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '2500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60631'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '251'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '4000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '4000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '4000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '4000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60631'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '822'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60631'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '22259.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '22259.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '22259.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '22259.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60631'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '4950.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '4450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '4450.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '4950.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60631'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '9000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '9000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '9000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '9000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '251'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '30'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '11872.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '13340.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '13340.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '11872.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '2170.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '2170.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60632'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '2800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '9300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '9300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '2800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '251'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '4551.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '4551.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '4551.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '4551.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '790.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '790.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '790.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '790.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '112'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '60636'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '4500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '4500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '4500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '4500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '90'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '100.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '30'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '500.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '322'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '3350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '2750.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '2750.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '3350.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '524'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '411'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '20.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '20.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '20.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '20.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '413'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '76.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '76.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '76.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '76.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6064'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '020'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '43300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '43400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '43400.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '43300.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6065'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '30'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat': {'V': '011'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '800.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'F'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '6065'},
# ...
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '200000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '200000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'PARC DES EXPOSITIONS (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '01'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '110'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '46339.44'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1311'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '405936.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '1125000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1312'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '78000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '52000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '120000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '360000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '13141'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '858180.14'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '354673.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '354673.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '880297.18'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1317'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContOp': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '607780.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '136458.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '136458.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeInfo', 'V': '136458.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '510'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContOp': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1549133.43'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '875000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '875000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeInfo', 'V': '875000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'MAISONS DE SANTE PLURIPRO. (M14)'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '01'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '111'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '172.80'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1311'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '429000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '114000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '114000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '435505.73'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1312'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '480000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '480000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '480000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '480000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '655146.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '157795.40'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '157795.40'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '631181.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '13141'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '2733739.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '546747.80'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '546747.80'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '2186991.20'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '1317'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '1300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '1300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '1300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'BudgetHorsRAR', 'V': '1300000.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '414'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContOp': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'D'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec': {'V': '2847981.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv': {'V': '624363.56'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '624363.56'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeInfo', 'V': '624363.56'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}},
#  {'{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature': {'V': '2313'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte': {'V': 'EQUIPEMENTS STRUCTURANTS ONET'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction': {'V': '01'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation': {'V': '113'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe': {'V': 'false'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD': {'V': 'R'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev': {'V': '0.00'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg': {'V': '0'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup': {'Code': 'MtOpeCumul', 'V': '713814.33'},
#   '{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup': {'Code': 'Section', 'V': 'I'}}]

# %%
lignes_budget_list2 = []

for ligne_budget_element in larbreentete.iter("{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget"):
    # Créez un dictionnaire pour stocker les informations de cette ligne budget
    ligne_budget_dict = {}
    
    # Parcourez les enfants de l'élément "LigneBudget"
    for sous_element in ligne_budget_element.getchildren():
        # Utilisez le nom de la balise comme clé et le texte à l'intérieur comme valeur
        ligne_budget_dict[sous_element.tag] = sous_element.attrib["V"]
    
    # Ajoutez le dictionnaire de cette ligne budget à la liste
    lignes_budget_list2.append(ligne_budget_dict)

lignes_budget_list2

df_bbb = pd.DataFrame(lignes_budget_list2)
df_bbb
# Out:
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Nature  \
# 0                                                60611
# 1                                                60611
# 2                                                60611
# 3                                                60611
# 4                                                60611
# ..                                                 ...
# 857                                               1313
# 858                                              13141
# 859                                               1317
# 860                                               2313
# 861                                               2313
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Fonction  \
# 0                                                   90
# 1                                                  251
# 2                                                  324
# 3                                                  322
# 4                                                  311
# ..                                                 ...
# 857                                                414
# 858                                                414
# 859                                                414
# 860                                                414
# 861                                                 01
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContNat  \
# 0                                                  011
# 1                                                  011
# 2                                                  011
# 3                                                  011
# 4                                                  011
# ..                                                 ...
# 857                                                NaN
# 858                                                NaN
# 859                                                NaN
# 860                                                NaN
# 861                                                NaN
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ArtSpe  \
# 0                                                false
# 1                                                false
# 2                                                false
# 3                                                false
# 4                                                false
# ..                                                 ...
# 857                                              false
# 858                                              false
# 859                                              false
# 860                                              false
# 861                                              false
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CodRD  \
# 0                                                    D
# 1                                                    D
# 2                                                    D
# 3                                                    D
# 4                                                    D
# ..                                                 ...
# 857                                                  R
# 858                                                  R
# 859                                                  R
# 860                                                  D
# 861                                                  R
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtBudgPrec  \
# 0                                              5500.00
# 1                                              1000.00
# 2                                               500.00
# 3                                              1210.00
# 4                                               450.00
# ..                                                 ...
# 857                                          655146.00
# 858                                         2733739.00
# 859                                         1300000.00
# 860                                         2847981.00
# 861                                                NaN
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPropNouv  \
# 0                                              8500.00
# 1                                               750.00
# 2                                               500.00
# 3                                              1210.00
# 4                                               450.00
# ..                                                 ...
# 857                                          157795.40
# 858                                          546747.80
# 859                                         1300000.00
# 860                                          624363.56
# 861                                                NaN
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtPrev  \
# 0                                              8500.00
# 1                                               750.00
# 2                                               500.00
# 3                                              1210.00
# 4                                               450.00
# ..                                                 ...
# 857                                          157795.40
# 858                                          546747.80
# 859                                         1300000.00
# 860                                          624363.56
# 861                                               0.00
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpBudg  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 857                                                  0
# 858                                                  0
# 859                                                  0
# 860                                                  0
# 861                                                  0
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}MtSup  \
# 0                                              5500.00
# 1                                              1000.00
# 2                                               500.00
# 3                                              1210.00
# 4                                               450.00
# ..                                                 ...
# 857                                          631181.00
# 858                                         2186991.20
# 859                                         1300000.00
# 860                                          624363.56
# 861                                          713814.33
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}CaracSup  \
# 0                                                    F
# 1                                                    F
# 2                                                    F
# 3                                                    F
# 4                                                    F
# ..                                                 ...
# 857                                                  I
# 858                                                  I
# 859                                                  I
# 860                                                  I
# 861                                                  I
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}TypOpBudg  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 857                                                NaN
# 858                                                NaN
# 859                                                NaN
# 860                                                NaN
# 861                                                NaN
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LibCpte  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 857                      EQUIPEMENTS STRUCTURANTS ONET
# 858                      EQUIPEMENTS STRUCTURANTS ONET
# 859                      EQUIPEMENTS STRUCTURANTS ONET
# 860                      EQUIPEMENTS STRUCTURANTS ONET
# 861                      EQUIPEMENTS STRUCTURANTS ONET
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}OpeCpteTiers  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 857                                                NaN
# 858                                                NaN
# 859                                                NaN
# 860                                                NaN
# 861                                                NaN
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}Operation  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 857                                                113
# 858                                                113
# 859                                                113
# 860                                                113
# 861                                                113
#
#     {http://www.minefi.gouv.fr/cp/demat/docbudgetaire}ContOp
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 857                                                NaN
# 858                                                NaN
# 859                                                NaN
# 860                                                113
# 861                                                NaN
#
# [862 rows x 16 columns]
